# %% [markdown]
# # Job Market for Data Professionals - Data Cleaning

# %%
# Import libraries 
import pandas as pd
import re
import numpy as np

# %%
jobs = pd.read_csv('jobs_all_base.csv')
jobs.head()
# Out:
#                                                Title           Location  \
# 0                                     Data Scientist           Den Haag
# 1                            Associate Scientist USP             Leiden
# 2                                 Cloud Engineer AWS          Amsterdam
# 3                                        Web Analist  Amsterdam Centrum
# 4  Senior Full Stack Software Developer (Python, ...   Utrecht Zuidwest
#
#           Company Salary          Since  Description     Company Url  \
# 0            HAYS    NaN  Net geplaatst          NaN       /cmp/Hays
# 1            HAYS    NaN  Net geplaatst          NaN       /cmp/Hays
# 2            HAYS    NaN  Net geplaatst          NaN       /cmp/Hays
# 3       DPG Media    NaN  Net geplaatst          NaN  /cmp/Dpg-Media
# 4  Zero foodwaste    NaN  Net geplaatst          NaN             NaN
#
#                        Industry      Company size
# 0  Human resources en personeel  5.001 tot 10.000
# 1  Human resources en personeel  5.001 tot 10.000
# 2  Human resources en personeel  5.001 tot 10.000
# 3                           NaN               NaN
# 4                           NaN               NaN

# %%
jobs.shape
# Out:
# (1500, 9)

# %%
jobs.dtypes
# Out:
# Title            object
# Location         object
# Company          object
# Salary           object
# Since            object
# Description     float64
# Company Url      object
# Industry         object
# Company size     object
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
# Top 15 uncleaned titles
jobs.Title.unique()
# Out:
# array(['Data Scientist', 'Associate Scientist USP', 'Cloud Engineer AWS',
#        ..., 'Data Engineer rol met AWS, Azure en/of Google Cloud',
#        'Openstaande Support vacature voor de toppers!',
#        'Microsoft Data Platform Consultant (BI)'], dtype=object)

# %%
og_titles = []

regular_expressions = [r'data[- ]anal[yi]st', r'data[- ]scien', r'data[- ]engineer', r'business[- ]anal', r'business[- ]intelli', r'machine learning[- ]engineer', r'artificial intelligence[- ]engi',r'translat', r'analytics[- ]consul', r'data[- consult]', r'data']

key_words = ["Data Engineer","Data Scientist","Data Analist","Data Analyst","Business Intelligence", "Business Analist", "Business Analyst", "Artificial Intelligence", "Machine Learning", "Data-"]
    
for title in jobs['Title']:
    for key in regular_expressions:
        match = re.search(key, title.lower())
        if match:
            og_titles.append(title)

# %%
len(og_titles)
# Out:
# 922

# %%
sorted(og_titles)
# Out:
# ['!Uniek!Meehelpen een nieuw Microsoft datawarehouse opzetten?',
#  '(Afstudeer)stages Business Intelligence binnen Asset Managem...',
#  '(Junior) Data Engineer (m/v)',
#  '(Junior) Data Engineer (m/v)',
#  '(Junior) Data Engineer (m/v)',
#  '(Lead) engineer installatietechniek (E en/of W) datacenters',
#  '(Lead) engineer installatietechniek (E en/of W) datacenters',
#  '(Senior) Data Engineer',
#  '(Senior) Data Engineer',
#  '(Senior) Data Engineer',
#  '(Senior) Data Scientist Healthcare',
#  '(Senior) Data Scientist Healthcare',
#  '(Senior) Data Scientist Healthcare',
#  'AI & Data Science Internship at ABN AMRO',
#  'AI & Data Science Internship at ABN AMRO',
#  'AI & Data Science Internship at ABN AMRO',
#  'Aantrekkelijke rol voor een Data Analist met BI-tooling',
#  'Aantrekkelijke rol voor een Data Analist met BI-tooling',
#  'Aantrekkelijke rol voor een Data Analist met BI-tooling',
#  'Afstudeerstage Data Scientist beeldherkenning',
#  'Afstudeerstage Data Scientist beeldherkenning',
#  'Afstudeerstage Data Scientist beeldherkenning',
#  'Afstudeerstagiaire Business Intelligence',
#  'Analist business intelligence bij Link Asset Services (senio...',
#  'Applicatiebeheerder / Data analist',
#  'Applicatiebeheerder / Data analist',
#  'Applicatiebeheerder / Data analist',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Artificial Intelligence Data Scientist vacature',
#  'Artificial Intelligence Data Scientist vacature',
#  'Artificial Intelligence Data Scientist vacature',
#  'Artificial Intelligence Translator (m/f)',
#  'Azure Data Platform Engineer',
#  'Azure Data Platform Engineer',
#  'BA Finance/Risk Data',
#  'BI Developer / Data Engineer / ETL / Duizenden gebruikers',
#  'BI Developer / Data Engineer / ETL / Duizenden gebruikers',
#  'BI Developer / Data Engineer / ETL / Duizenden gebruikers',
#  'BI Specialist/Data Engineer o.a. SQLserver, Azure, ETL, SSIS',
#  'BI Specialist/Data Engineer o.a. SQLserver, Azure, ETL, SSIS',
#  'BI Specialist/Data Engineer o.a. SQLserver, Azure, ETL, SSIS',
#  'BI and Data Insight Lead',
#  'BI and Data Insight Lead',
#  'Ben jij de technische data consultant ?',
#  'Ben jij de technische data consultant ?',
#  'Big Data / Software Traineeship in Amsterdam',
#  'Big Data / Software Traineeship in Amsterdam',
#  'Big Data Analytics Engineer',
#  'Big Data Analytics Engineer',
#  'Big Data Engineer',
#  'Big Data Engineer',
#  'Big Data Engineer',
#  'Big Data Operations Engineer',
#  'Big Data Operations Engineer',
#  'Big Data Specialist bij het Spaarne Gasthuis',
#  'Big Data Specialist bij het Spaarne Gasthuis',
#  'BigData Engineer met SQL en Python',
#  'BigData Engineer met SQL en Python',
#  'BigData Engineer met SQL en Python',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist (32-40 uur)',
#  'Business Analist Customer Contact Cent',
#  'Business Analist Finance & Risk Hypotheken',
#  'Business Analist Ketenmonitoring',
#  'Business Analist Zorg met goede arbeidsvoorwaarden!',
#  'Business Analist in publieke sector',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst (Financial Markets)',
#  'Business Analyst (Non IT)',
#  'Business Analyst - Dashboarding Expert',
#  'Business Analyst - Statutory & Regulatory Reporting (AnaCred...',
#  'Business Analyst - Supply Chain Professional',
#  'Business Analyst Controller',
#  'Business Analyst with an Asset Management specialty.',
#  'Business Intelligence (BI) professional',
#  'Business Intelligence / Data Warehouse Developer',
#  'Business Intelligence / Data Warehouse Developer',
#  'Business Intelligence / Data Warehouse Developer',
#  'Business Intelligence / ICT Stagiair(e)',
#  'Business Intelligence Analist vacature',
#  'Business Intelligence Analist vacature',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant in de ZORG!',
#  'Business Intelligence Developer',
#  'Business Intelligence Engineer vacature',
#  'Business Intelligence Engineer vacature',
#  'Business Intelligence Lead',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist BI',
#  'Business Intelligence Specialist | Tiel',
#  'Business Intelligence Specialist/ Datawarehouse / ETL',
#  'Business Intelligence Specialist/ Datawarehouse / ETL',
#  'Business Intelligence in IT',
#  'Business Intelligence ontwikkelaar',
#  'Business Intelligence specialist (zorg sector)',
#  'Business Intelligence/ETL specialist (flexibel tijd indelen)',
#  'Business Partner Digital Data',
#  'Business analist (senior)',
#  'Business analist JO17627',
#  'Business analyst',
#  'Business analyst & inkoper',
#  'Business intelligence- (BI-)ontwikkelaar',
#  'CRM Data Analyst',
#  'CRM Data Analyst',
#  'CRM Data Analyst',
#  'Chapter Lead Business Analyst - Finance Information Manageme...',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Claims Technician / Data Analyst',
#  'Claims Technician / Data Analyst',
#  'Claims Technician / Data Analyst',
#  'Commercial Data Analyst Schiphol',
#  'Commercial Data Analyst Schiphol',
#  'Commercial Data Analyst Schiphol',
#  'Compensation & Benefits Data Analyst',
#  'Compensation & Benefits Data Analyst',
#  'Compensation & Benefits Data Analyst',
#  'Consultant Business Intelligence',
#  'Consultant/Senior Data Analist',
#  'Consultant/Senior Data Analist',
#  'Consultant/Senior Data Analist',
#  'Consulting Operations Specialist | Business analytics softwa...',
#  'Credit Risk Data Analist',
#  'Credit Risk Data Analist',
#  'Credit Risk Data Analist',
#  'Customer Data Analist (SAS/R/Python, SQL, IBM Cognos) - Leeu...',
#  'Customer Data Analist (SAS/R/Python, SQL, IBM Cognos) - Leeu...',
#  'Customer Data Analist (SAS/R/Python, SQL, IBM Cognos) - Leeu...',
#  'Customer Data Analyst Leeuwarden',
#  'Customer Data Analyst Leeuwarden',
#  'Customer Data Analyst Leeuwarden',
#  'Customs Advisor Data Analist',
#  'Customs Advisor Data Analist',
#  'Customs Advisor Data Analist',
#  'DATA SCIENTIST PERMANENT POSITION SOUTH-HOLLAND',
#  'DATA SCIENTIST PERMANENT POSITION SOUTH-HOLLAND',
#  'DATA SCIENTIST PERMANENT POSITION SOUTH-HOLLAND',
#  'Data & BI Analyst',
#  'Data & BI Analyst',
#  'Data & Growth Engineer',
#  'Data & Growth Engineer',
#  'Data & Market Analist B2B',
#  'Data & Market Analist B2B',
#  'Data (Cloud) Engineer in de regio Utrecht',
#  'Data (Cloud) Engineer in de regio Utrecht',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist (Junior/Medior)',
#  'Data Analist (Junior/Medior)',
#  'Data Analist (Junior/Medior)',
#  'Data Analist (Medior)',
#  'Data Analist (Medior)',
#  'Data Analist (Medior)',
#  'Data Analist (marketing)',
#  'Data Analist (marketing)',
#  'Data Analist (marketing)',
#  'Data Analist Jeugdzorg en Sociaal Domein 16 u p/w',
#  'Data Analist Jeugdzorg en Sociaal Domein 16 u p/w',
#  'Data Analist Jeugdzorg en Sociaal Domein 16 u p/w',
#  'Data Analist met wisselende opdrachten, regio Randstad)',
#  'Data Analist met wisselende opdrachten, regio Randstad)',
#  'Data Analist met wisselende opdrachten, regio Randstad)',
#  'Data Analist regio NB',
#  'Data Analist regio NB',
#  'Data Analist regio NB',
#  'Data Analist/ETL Ontwikkelaar',
#  'Data Analist/ETL Ontwikkelaar',
#  'Data Analist/ETL Ontwikkelaar',
#  'Data Analist/ETL ontwikkelaar',
#  'Data Analist/ETL ontwikkelaar',
#  'Data Analist/ETL ontwikkelaar',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst (Marketing & UX) for iptiQ EMEA P&C',
#  'Data Analyst (Marketing & UX) for iptiQ EMEA P&C',
#  'Data Analyst (Marketing & UX) for iptiQ EMEA P&C',
#  'Data Analyst (Remote / Netherlands)',
#  'Data Analyst (Remote / Netherlands)',
#  'Data Analyst (Remote / Netherlands)',
#  'Data Analyst - App Optimisation',
#  'Data Analyst - App Optimisation',
#  'Data Analyst - App Optimisation',
#  'Data Analyst - Product',
#  'Data Analyst - Product',
#  'Data Analyst - Product',
#  'Data Analyst / Reporting Expert',
#  'Data Analyst / Reporting Expert',
#  'Data Analyst / Reporting Expert',
#  'Data Analyst Intern',
#  'Data Analyst Intern',
#  'Data Analyst Intern',
#  'Data Analyst Koppelingen Maatwerk Sofware | Advisering',
#  'Data Analyst Koppelingen Maatwerk Sofware | Advisering',
#  'Data Analyst Koppelingen Maatwerk Sofware | Advisering',
#  'Data Analyst | Business Intelligence Expert | PowerBI | Fina...',
#  'Data Analyst | Business Intelligence Expert | PowerBI | Fina...',
#  'Data Analyst | Business Intelligence Expert | PowerBI | Fina...',
#  'Data Analyst | Business Intelligence Expert | PowerBI | Fina...',
#  'Data Analytics Manager at Customer Support',
#  'Data Analytics Manager at Customer Support',
#  'Data Analytics specialist - consultant',
#  'Data Analytics specialist - consultant',
#  'Data Architect',
#  'Data Architect',
#  'Data Architect | Cloud | AI | Financiële dienstverlener',
#  'Data Architect | Cloud | AI | Financiële dienstverlener',
#  'Data Architect | Cloud | AI | Financiële dienstverlener | Ro...',
#  'Data Architect | Cloud | AI | Financiële dienstverlener | Ro...',
#  'Data Center Engineer',
#  'Data Center Engineer',
#  'Data Controller',
#  'Data Controller',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer (2 fte)',
#  'Data Engineer (2 fte)',
#  'Data Engineer (2 fte)',
#  'Data Engineer (ervaren)',
#  'Data Engineer (ervaren)',
#  'Data Engineer (ervaren)',
#  'Data Engineer (permanent position)',
#  'Data Engineer (permanent position)',
#  'Data Engineer (permanent position)',
#  'Data Engineer - Utrecht',
#  'Data Engineer - Utrecht',
#  'Data Engineer - Utrecht',
#  'Data Engineer AWS/GCP (Temporary position)',
#  'Data Engineer AWS/GCP (Temporary position)',
#  'Data Engineer AWS/GCP (Temporary position)',
#  'Data Engineer Consultant (Azure, AWS, Google Cloud)',
#  'Data Engineer Consultant (Azure, AWS, Google Cloud)',
#  'Data Engineer Consultant (Azure, AWS, Google Cloud)',
#  'Data Engineer Conusltant',
#  'Data Engineer Conusltant',
#  'Data Engineer Conusltant',
#  'Data Engineer Experienced in AWS or GCP (Permanent Position)',
#  'Data Engineer Experienced in AWS or GCP (Permanent Position)',
#  'Data Engineer Experienced in AWS or GCP (Permanent Position)',
#  'Data Engineer High-Tech',
#  'Data Engineer High-Tech',
#  'Data Engineer High-Tech',
#  'Data Engineer Intern',
#  'Data Engineer Intern',
#  'Data Engineer Intern',
#  'Data Engineer PortalOne',
#  'Data Engineer PortalOne',
#  'Data Engineer PortalOne',
#  'Data Engineer en Data Modelleur voor Wiskundigen',
#  'Data Engineer en Data Modelleur voor Wiskundigen',
#  'Data Engineer en Data Modelleur voor Wiskundigen',
#  'Data Engineer met uitstekende voorwaarden! (interne functie)',
#  'Data Engineer met uitstekende voorwaarden! (interne functie)',
#  'Data Engineer met uitstekende voorwaarden! (interne functie)',
#  'Data Engineer rol met AWS en Azure',
#  'Data Engineer rol met AWS en Azure',
#  'Data Engineer rol met AWS en Azure',
#  'Data Engineer rol met AWS, Azure en/of Google Cloud',
#  'Data Engineer rol met AWS, Azure en/of Google Cloud',
#  'Data Engineer rol met AWS, Azure en/of Google Cloud',
#  'Data Engineer rol met ETL, SSIS, SSAS, SSRS en Cloud',
#  'Data Engineer rol met ETL, SSIS, SSAS, SSRS en Cloud',
#  'Data Engineer rol met ETL, SSIS, SSAS, SSRS en Cloud',
#  'Data Engineer | AWS | Cloud | Finance',
#  'Data Engineer | AWS | Cloud | Finance',
#  'Data Engineer | AWS | Cloud | Finance',
#  'Data Governance Officer Tribe Data Management',
#  'Data Governance Officer Tribe Data Management',
#  'Data Management Analyst',
#  'Data Management Analyst',
#  'Data Management Professional (m/f)',
#  'Data Management Professional (m/f)',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Platform Lead',
#  'Data Platform Lead',
#  'Data Platform Product Owner (Azure)',
#  'Data Platform Product Owner (Azure)',
#  'Data Science Consultant (JUNIOR/MEDIOR/SENIOR)',
#  'Data Science Consultant (JUNIOR/MEDIOR/SENIOR)',
#  'Data Science Consultant (JUNIOR/MEDIOR/SENIOR)',
#  'Data Science Consultant voor BigData en ML/AI oplossingen',
#  'Data Science Consultant voor BigData en ML/AI oplossingen',
#  'Data Science Consultant voor BigData en ML/AI oplossingen',
#  'Data Science Development Program Den Haag',
#  'Data Science Development Program Den Haag',
#  'Data Science Development Program Den Haag',
#  'Data Science Intern',
#  'Data Science Intern',
#  'Data Science Intern',
#  'Data Science en Engineer Inhouse Combinatie functie',
#  'Data Science en Engineer Inhouse Combinatie functie',
#  'Data Science en Engineer Inhouse Combinatie functie',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist & Engineer',
#  'Data Scientist & Engineer',
#  'Data Scientist & Engineer',
#  'Data Scientist - Retailmonitor',
#  'Data Scientist - Retailmonitor',
#  'Data Scientist - Retailmonitor',
#  'Data Scientist Conversational AI (f/m)',
#  'Data Scientist Conversational AI (f/m)',
#  'Data Scientist Conversational AI (f/m)',
#  'Data Scientist Medior',
#  'Data Scientist Medior',
#  'Data Scientist Medior',
#  'Data Scientist en een passie voor Health',
#  'Data Scientist en een passie voor Health',
#  'Data Scientist en een passie voor Health',
#  'Data Scientist in Brabant met variërende opdrachten',
#  'Data Scientist in Brabant met variërende opdrachten',
#  'Data Scientist in Brabant met variërende opdrachten',
#  'Data Scientist in publieke sector',
#  'Data Scientist in publieke sector',
#  'Data Scientist in publieke sector',
#  'Data Scientist predictive oplossingen medisch',
#  'Data Scientist predictive oplossingen medisch',
#  'Data Scientist predictive oplossingen medisch',
#  'Data Scientist – Product Owner (EN)',
#  'Data Scientist – Product Owner (EN)',
#  'Data Scientist – Product Owner (EN)',
#  'Data Scientist/Analist financieel-economische criminaliteit',
#  'Data Scientist/Analist financieel-economische criminaliteit',
#  'Data Scientist/Analist financieel-economische criminaliteit',
#  'Data Scientist/Commercial Analyst BritNed',
#  'Data Scientist/Commercial Analyst BritNed',
#  'Data Scientist/Commercial Analyst BritNed',
#  'Data Software Engineer (ref. nr. 12037)',
#  'Data Software Engineer (ref. nr. 12037)',
#  'Data Stewardship Coordinator',
#  'Data Stewardship Coordinator',
#  'Data Subject Matter Expert - Corporate Real Estate',
#  'Data Subject Matter Expert - Corporate Real Estate',
#  'Data Visualization expert',
#  'Data Visualization expert',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist - Zutphen',
#  'Data analist - Zutphen',
#  'Data analist - Zutphen',
#  'Data analist/GIS specialist Vastgoedadvisering',
#  'Data analist/GIS specialist Vastgoedadvisering',
#  'Data analist/GIS specialist Vastgoedadvisering',
#  'Data and Computer Science Internship',
#  'Data and Computer Science Internship',
#  'Data architect',
#  'Data architect',
#  'Data custodian',
#  'Data custodian',
#  'Data en proces consultant',
#  'Data en proces consultant',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data enthousiasten gezocht voor toffe traineeship!',
#  'Data enthousiasten gezocht voor toffe traineeship!',
#  'Data governance consultant',
#  'Data governance consultant',
#  'Data modeling specialist (in dienst bij Yacht)',
#  'Data modeling specialist (in dienst bij Yacht)',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist voor Big Data marketing specialist',
#  'Data scientist voor Big Data marketing specialist',
#  'Data scientist voor Big Data marketing specialist',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data-Analist',
#  'Data-Analist',
#  'Data-Analist',
#  'Data-Analist',
#  'Data-Analist',
#  'Data-Analist',
#  'Data-Analist omgevingsdienst',
#  'Data-Analist omgevingsdienst',
#  'Data-Analist omgevingsdienst',
#  'Data-Scientist, de slimste uit de klas! (MAGNA)Cum Laude',
#  'Data-Scientist, de slimste uit de klas! (MAGNA)Cum Laude',
#  'Data-Scientist, de slimste uit de klas! (MAGNA)Cum Laude',
#  'Data-analist Bodem en Ondergrond',
#  'Data-analist Bodem en Ondergrond',
#  'Data-analist Bodem en Ondergrond',
#  'Data-analist Jeugdzorg en Sociaal Domein',
#  'Data-analist Jeugdzorg en Sociaal Domein',
#  'Data-analist Jeugdzorg en Sociaal Domein',
#  'Data-analist/scientist',
#  'Data-analist/scientist',
#  'Data-analist/scientist',
#  'Data-engineer Splunk',
#  'Data-engineer Splunk',
#  'Data-engineer Splunk',
#  'Data-engineer bij Kijkwijzer!',
#  'Data-engineer bij Kijkwijzer!',
#  'Data-engineer bij Kijkwijzer!',
#  'Data-engineer per 1 september',
#  'Data-engineer per 1 september',
#  'Data-engineer per 1 september',
#  'Data-scientist',
#  'Data-scientist',
#  'Data-scientist',
#  'Database Beheerder bij een innovatief, technologisch bedrijf',
#  'Database Marketeer',
#  'Database specialist gezocht!',
#  'Datacenter Engineer',
#  'Datacenter Engineer',
#  'Datalake/Hadoop Beheerder',
#  'Datalake/Hadoop Beheerder',
#  'Dataspecialist',
#  'Dataspecialist',
#  'Datawarehouse Engineer',
#  'Datawarehouse Engineer',
#  'Datawarehouse Engineer',
#  'DevOps Engineer - Application Manager Self Service en Data S...',
#  'DevOps Engineer - Application Manager Self Service en Data S...',
#  'DevOps Engineer - Data Management Developer',
#  'DevOps Engineer - Data Management Developer',
#  'DevOps Engineer - Developer Self Service & Data Science',
#  'DevOps Engineer - Developer Self Service & Data Science',
#  'DevOps Engineer - Developer Self Service & Data Science',
#  'Developer Business Intelligence en Datawarehouse',
#  'Developer Business Intelligence en Datawarehouse',
#  'Director Business Analysis and Planning',
#  'Docent Geo-data & Geo-ict Almere',
#  'Docent Geo-data & Geo-ict Almere',
#  'Docent Software Engineering & Big data',
#  'Ecommerce Operations/ CS Data Analyst',
#  'Ecommerce Operations/ CS Data Analyst',
#  'Ecommerce Operations/ CS Data Analyst',
#  'Energie Data Analist Mid-Office',
#  'Energie Data Analist Mid-Office',
#  'Energie Data Analist Mid-Office',
#  'Enterprise Data Scientist',
#  'Enterprise Data Scientist',
#  'Enterprise Data Scientist',
#  'Ervaren met T-SQL, data modelling en ETL processen?',
#  'Ervaren met T-SQL, data modelling en ETL processen?',
#  'Fault Data Analyst',
#  'Fault Data Analyst',
#  'Fault Data Analyst',
#  'Financial Reporting Data Expert',
#  'Financial Reporting Data Expert',
#  'Financieel Consultant Business Intelligence',
#  'Google Cloud Data Engineer',
#  'Google Cloud Data Engineer',
#  'Google Cloud Data Engineer',
#  'HBO Meewerkstage Data Science',
#  'HBO Meewerkstage Data Science',
#  'HBO Meewerkstage Data Science',
#  'Head of Data and Business Technology Engineering',
#  'Head of Data and Business Technology Engineering',
#  'IT Traineeship Data Infra Engineer',
#  'IT Traineeship Data Infra Engineer',
#  'IT-traineeship Data Infra Engineer APG',
#  'IT-traineeship Data Infra Engineer APG',
#  'Informatie Analist / Data Analist',
#  'Informatie Analist / Data Analist',
#  'Informatie Analist / Data Analist',
#  'Informatie Analist / Data Analist / BI',
#  'Informatie Analist / Data Analist / BI',
#  'Informatie Analist / Data Analist / BI',
#  'Information & Data Architect(e) Clearing',
#  'Information & Data Architect(e) Clearing',
#  'Inhouse Data Science Positie voor avonturiers',
#  'Inhouse Data Science Positie voor avonturiers',
#  'Inhouse Data Science Positie voor avonturiers',
#  'Interim vacature - Data analist',
#  'Interim vacature - Data analist',
#  'Interim vacature - Data analist',
#  'Internship Data Science',
#  'Internship Data Science',
#  'Internship Data Science',
#  'Jr. Business Analyst',
#  'Junior Consultant Business Intelligence',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist Banking',
#  'Junior Data Analist Banking',
#  'Junior Data Analist Banking',
#  'Junior Data Analist Remediation',
#  'Junior Data Analist Remediation',
#  'Junior Data Analist Remediation',
#  'Junior Data Consultant',
#  'Junior Data Consultant',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Management Consultant',
#  'Junior Data Management Consultant',
#  'Junior Marketing Data Scientist',
#  'Junior Marketing Data Scientist',
#  'Junior Marketing Data Scientist',
#  'Junior Strategy & Business Analyst',
#  'Junior Strategy & Business Analyst',
#  'Junior dataspecialist',
#  'Junior dataspecialist',
#  'Lead Data Engineer (PreSales)',
#  'Lead Data Engineer (PreSales)',
#  'Lead Data Engineer (PreSales)',
#  'Lead Data Modeler',
#  'Lead Data Modeler',
#  'Lead Data Science',
#  'Lead Data Science',
#  'Lead Data Science',
#  'Lead Data Scientist (Artificial Intellingence- PHD Level)',
#  'Lead Data Scientist (Artificial Intellingence- PHD Level)',
#  'Lead Data Scientist (Artificial Intellingence- PHD Level)',
#  'MECHANICAL ENGINEER DATA CENTRES (MCF)',
#  'MECHANICAL ENGINEER DATA CENTRES (MCF)',
#  'MEDIOR/SENIOR DATA SCIENTIST',
#  'MEDIOR/SENIOR DATA SCIENTIST',
#  'MEDIOR/SENIOR DATA SCIENTIST',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer (junior/medior)',
#  'Machine learning engineer',
#  'Manager Data Analytics (in Utrecht, NL)',
#  'Manager Data Analytics (in Utrecht, NL)',
#  'Manager Team Databeheer',
#  'Marketing Data Specialist',
#  'Marketing Data Specialist',
#  'Master Data Specialist',
#  'Master Data Specialist',
#  'Master Data Specialist / Jr Data Analyst',
#  'Master Data Specialist / Jr Data Analyst',
#  'Master Data Specialist / Jr Data Analyst',
#  'Medior Business Intelligence (BI) consultant',
#  'Medior Consultant Business Intelligence',
#  'Medior Data Consultant',
#  'Medior Data Consultant',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Management Consultant',
#  'Medior Data Management Consultant',
#  'Medior Marketing Data Scientist',
#  'Medior Marketing Data Scientist',
#  'Medior Marketing Data Scientist',
#  'Medior/ Senior Data Analist met Visualisatie en Engineering',
#  'Medior/ Senior Data Analist met Visualisatie en Engineering',
#  'Medior/ Senior Data Analist met Visualisatie en Engineering',
#  'Medior/Senior Business Analyst',
#  'Medior/Senior Business Analyst',
#  'Medior/Senior Data Engineer',
#  'Medior/Senior Data Engineer',
#  'Medior/Senior Data Engineer',
#  'Microsoft Business Intelligence (cloud) Specialist',
#  'Microsoft Business Intelligence (cloud) Specialist',
#  'Microsoft Business Intelligence Consultant',
#  'Microsoft Data Platform Consultant (BI)',
#  'Microsoft Data Platform Consultant (BI)',
#  'Microsoft datawarehouse/BI ontwikkelaar',
#  'Modelling Data Analyst (Asset and Liability Management) 1',
#  'Modelling Data Analyst (Asset and Liability Management) 1',
#  'Modelling Data Analyst (Asset and Liability Management) 1',
#  'Modelling Data Analyst Liability Management)',
#  'Modelling Data Analyst Liability Management)',
#  'Modelling Data Analyst Liability Management)',
#  'Nieuwe Business Intelligence Consultants gezocht!',
#  'Ondernemende business analist',
#  'Parttime Data Analist/Scientist GEO',
#  'Parttime Data Analist/Scientist GEO',
#  'Parttime Data Analist/Scientist GEO',
#  'Parttime: Business Intelligence analist',
#  'Perfecte Computer Vision & Machine Learning Engineer',
#  'PhD Position Deep Learning from Unlabelled Sensor Data in La...',
#  'PhD Position Deep Learning from Unlabelled Sensor Data in La...',
#  'PhD Position New Machine Learning Strategies for Data Scarce...',
#  'PhD Position New Machine Learning Strategies for Data Scarce...',
#  'PhD position on Learning Analytics and Educational Data Mini...',
#  'PhD position on Learning Analytics and Educational Data Mini...',
#  'Postdoc - Bioinformatics Translational Oncology',
#  'Postdoc - Translational Oncology / Molecular Pathology',
#  'Postdoctoral fellowship on causal inference in big-data heal...',
#  'Postdoctoral fellowship on causal inference in big-data heal...',
#  'Pre-Sales Data Engineer Utrecht,',
#  'Pre-Sales Data Engineer Utrecht,',
#  'Pre-Sales Data Engineer Utrecht,',
#  'Product Owner Business Intelligence',
#  'Product Owner Data logistiek',
#  'Product Owner Data logistiek',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Project Manager Climate Adaptation Report and Data Platform',
#  'Project Manager Climate Adaptation Report and Data Platform',
#  'Python Engineer (Data driven)',
#  'Python Engineer (Data driven)',
#  'SAP FICO Business Analyst',
#  'SCRUM Business Analist / Development Engineer',
#  'SQL-server database beheerder',
#  'Scientific Data Engineer',
#  'Scientific Data Engineer',
#  'Scientific Data Engineer',
#  'Senior Analytics Consultant (f/m/d), Expert on TIBCO Spotfir...',
#  'Senior Business Analist Fraud & Risk',
#  'Senior Business Analist SAP BW (BW/4HANA)',
#  'Senior Business Analyst COORF Accounting Tribe',
#  'Senior Business Intelligence (BI) consultant',
#  'Senior Business Intelligence (DWH) Ontwikkelaar',
#  'Senior Business Intelligence Consultant',
#  'Senior Business Intelligence Developer',
#  'Senior Consultant Business Intelligence',
#  'Senior Data Analist Remediation',
#  'Senior Data Analist Remediation',
#  'Senior Data Analist Remediation',
#  'Senior Data Consultant',
#  'Senior Data Consultant',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer Azure',
#  'Senior Data Engineer Azure',
#  'Senior Data Engineer Azure',
#  'Senior Data Engineer BI domein Commercie - Utrecht',
#  'Senior Data Engineer BI domein Commercie - Utrecht',
#  'Senior Data Engineer BI domein Commercie - Utrecht',
#  'Senior Data Engineer FR&R',
#  'Senior Data Engineer FR&R',
#  'Senior Data Engineer FR&R',
#  'Senior Data Engineer/Architect',
#  'Senior Data Engineer/Architect',
#  'Senior Data Engineer/Architect',
#  'Senior Data Management Consultant',
#  'Senior Data Management Consultant',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist - Amsterdam',
#  'Senior Data Scientist - Amsterdam',
#  'Senior Data Scientist - Amsterdam',
#  'Senior Data Scientist – Fixed Networks',
#  'Senior Data Scientist – Fixed Networks',
#  'Senior Data Scientist – Fixed Networks',
#  'Senior Data Transcript Engineer',
#  'Senior Data Transcript Engineer',
#  'Senior Data-Scientist',
#  'Senior Data-Scientist',
#  'Senior Data-Scientist',
#  'Senior Data-analist',
#  'Senior Data-analist',
#  'Senior Data-analist',
#  'Senior Database beheerder',
#  'Senior Java Software Engineer - Data Exchange',
#  'Senior Java Software Engineer - Data Exchange',
#  'Senior Machine Learning Engineer',
#  'Senior Marketing Data Scientist',
#  'Senior Marketing Data Scientist',
#  'Senior Marketing Data Scientist',
#  'Senior Specialist - Data Architect within the ICT Department...',
#  'Senior Specialist - Data Architect within the ICT Department...',
#  'Senior Technology Data Engineer',
#  'Senior Technology Data Engineer',
#  'Senior Technology Data Engineer',
#  'Slimme junior data-analist/ programmeur',
#  'Slimme junior data-analist/ programmeur',
#  'Slimme junior data-analist/ programmeur',
#  'Software Engineer - Data Engineering Internship',
#  'Software Engineer - Data Engineering Internship',
#  'Software Engineer - Data Engineering Internship',
#  'Sr. Business Intelligence Developer',
#  "Sr. Data Engineer (REST api's)",
#  "Sr. Data Engineer (REST api's)",
#  "Sr. Data Engineer (REST api's)",
#  'Stagiaire Business Intelligence',
#  'TZO 1: Clinical Data Science: PhD-student for cancer treatme...',
#  'TZO 1: Clinical Data Science: PhD-student for cancer treatme...',
#  'TZO 1: Clinical Data Science: PhD-student for cancer treatme...',
#  'Teamleider Business Intelligence',
#  'Teammanager business analytics',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Technical Product Manager, Data',
#  'Technisch Data Analist',
#  'Technisch Data Analist',
#  'Technisch Data Analist',
#  'Thesis Research - Business Intelligence',
#  'Trainee Business Intelligence Consultant',
#  'Trainee Data Engineer | Lady Legends',
#  'Trainee Data Engineer | Lady Legends',
#  'Trainee Data Engineer | Lady Legends',
#  'Traineeship Business Analist (Pensioenen)',
#  'Traineeship Data',
#  'Tv zoekt Data Engineers',
#  'Tv zoekt Data Engineers',
#  'Tv zoekt Data Engineers',
#  'WO Traineeship Data Analist in omgeving Arnhem',
#  'WO Traineeship Data Analist in omgeving Arnhem',
#  'WO Traineeship Data Analist in omgeving Arnhem',
#  'big data specialist',
#  'big data specialist',
#  'data scientist',
#  'data scientist',
#  'data scientist']

# %%
og_titles = set(og_titles)

# %%
# Examine titles that dont' fall the the categories above

jobs[~jobs['Title'].isin(og_titles)]['Title'].value_counts()
# Out:
# Software Engineer                         8
# Business Controller                       7
# Informatiemanager                         6
# DevOps Engineer                           5
# Support Engineer                          4
#                                          ..
# Concerncontroller (32-36) - via K+V       1
# Microsoft SSIS (ETL) ontwikkelaar         1
# Junior Inkoper                            1
# BIM modelleur Werktuigbouw, Rotterdam     1
# Policy Advisor Diversity and Inclusion    1
# Name: Title, Length: 985, dtype: int64

# %% [markdown]
# We will drop the above titles from our analysis, as they don't fall to the traditional categories of data professionals that we want to examine

# %%
jobs = jobs[jobs['Title'].isin(og_titles)]
print(jobs.shape)
jobs.head()
# Out:
# (413, 9)
#                                                 Title  Location  \
# 0                                      Data Scientist  Den Haag
# 10            Director Business Analysis and Planning  Schiphol
# 14                      Chapter Lead Data Engineering    Diemen
# 15                                 Database Marketeer  Schiedam
# 17  Business Analyst with an Asset Management spec...   Utrecht
#
#                         Company                     Salary              Since  \
# 0                          HAYS                        NaN      Net geplaatst
# 10               Liberty Global                        NaN  Vandaag geplaatst
# 14                   Tempo-Team  €4.000 - €5.400 per maand  Vandaag geplaatst
# 15  Lefit Recruitment & Interim                        NaN  Vandaag geplaatst
# 17            De Staffing Groep                        NaN  Vandaag geplaatst
#
#     Description             Company Url                      Industry  \
# 0           NaN               /cmp/Hays  Human resources en personeel
# 10          NaN     /cmp/Liberty-Global                           NaN
# 14          NaN        /cmp/Tempo--team  Human resources en personeel
# 15          NaN                     NaN                           NaN
# 17          NaN  /cmp/De-Staffing-Groep                           NaN
#
#         Company size
# 0   5.001 tot 10.000
# 10   Meer dan 10.000
# 14   1.001 tot 5.000
# 15               NaN
# 17               NaN

# %%
# Group data into categories

categories =  ["Data Engineer","Data Scientist", "Data Analyst", "Business Intelligence Dev/Con", "Business Analyst", "Artificial Intelligence", "Machine Learning"]
    
grouped_titles = [] 

for title in jobs['Title']:
    da = re.search(r'\bdata*[\w]+\b.*\banal[yi]st', title.lower())

    ds = re.search(r'data[- ]scien', title.lower())
    
    
    de = re.search(r'\bdata*[\w]+\b.*\bengineer*[\w]+\b.*?$', title.lower())
    ba = re.search(r'business[- \w]+anal|anal[yi]st', title.lower())
    bi = re.search(r'business[- ]intelli|\bbi\b.', title.lower())
    ml = re.search(r'machine learning[- ]engineer', title.lower())
    ai = re.search(r'artiial intelligence[- ]engi', title.lower())
    tr = re.search(r'translat', title.lower())
    cs = re.search(r'consultant', title.lower())
    if da:
        title = "Data Analyst"
    elif ds:
        title = "Data Scientist"
    elif de:
        title = "Data Engineer"
    elif ba:
        title = "Business Analyst"
    elif bi:
        title = "Business Intelligence Consultant/Engineer"
    elif ml:
        title = "Data Engineer"
    elif ai:
        title = "Data Engineer"
    elif tr:
        title = "Translator"
    elif cs:
        title = "Analytics Consultant"
    else:
        title = "Other"
    
    grouped_titles.append(title)

# %%
jobs['Title'].value_counts().head(15)
# Out:
# Data Engineer                                         15
# Data Scientist                                        15
# Data Analist                                          12
# Business Intelligence Specialist                      10
# Business Intelligence Consultant                       7
# Data analist                                           7
# Senior Data Engineer                                   6
# Senior Data Scientist                                  4
# Data Analyst                                           4
# Tech Lead Data Engineering                             3
# Business Analist                                       3
# Datawarehouse Engineer                                 3
# Business Analyst                                       3
# Data engineer                                          3
# Microsoft Business Intelligence (cloud) Specialist     2
# Name: Title, dtype: int64

# %%
jobs['Title Grouped'] = grouped_titles

# %%
sorted(list(jobs['Title'][jobs['Title Grouped']=='Other']))
# Out:
# ['!Uniek!Meehelpen een nieuw Microsoft datawarehouse opzetten?',
#  '(Lead) engineer installatietechniek (E en/of W) datacenters',
#  'BA Finance/Risk Data',
#  'Big Data / Software Traineeship in Amsterdam',
#  'Big Data Specialist bij het Spaarne Gasthuis',
#  'BigData Engineer met SQL en Python',
#  'Business Partner Digital Data',
#  'Data Analytics Manager at Customer Support',
#  'Data Architect',
#  'Data Architect | Cloud | AI | Financiële dienstverlener',
#  'Data Architect | Cloud | AI | Financiële dienstverlener | Ro...',
#  'Data Controller',
#  'Data Governance Officer Tribe Data Management',
#  'Data Management Professional (m/f)',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Platform Lead',
#  'Data Platform Product Owner (Azure)',
#  'Data Stewardship Coordinator',
#  'Data Subject Matter Expert - Corporate Real Estate',
#  'Data Visualization expert',
#  'Data and Computer Science Internship',
#  'Data architect',
#  'Data custodian',
#  'Data enthousiasten gezocht voor toffe traineeship!',
#  'Data modeling specialist (in dienst bij Yacht)',
#  'Database Beheerder bij een innovatief, technologisch bedrijf',
#  'Database Marketeer',
#  'Database specialist gezocht!',
#  'Datalake/Hadoop Beheerder',
#  'Dataspecialist',
#  'DevOps Engineer - Application Manager Self Service en Data S...',
#  'DevOps Engineer - Data Management Developer',
#  'Docent Geo-data & Geo-ict Almere',
#  'Docent Software Engineering & Big data',
#  'Ervaren met T-SQL, data modelling en ETL processen?',
#  'Financial Reporting Data Expert',
#  'Information & Data Architect(e) Clearing',
#  'Junior dataspecialist',
#  'Lead Data Modeler',
#  'MECHANICAL ENGINEER DATA CENTRES (MCF)',
#  'Manager Data Analytics (in Utrecht, NL)',
#  'Manager Team Databeheer',
#  'Marketing Data Specialist',
#  'Master Data Specialist',
#  'PhD Position Deep Learning from Unlabelled Sensor Data in La...',
#  'PhD Position New Machine Learning Strategies for Data Scarce...',
#  'PhD position on Learning Analytics and Educational Data Mini...',
#  'Postdoctoral fellowship on causal inference in big-data heal...',
#  'Product Owner Data logistiek',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Project Manager Climate Adaptation Report and Data Platform',
#  'Python Engineer (Data driven)',
#  'SQL-server database beheerder',
#  'Senior Database beheerder',
#  'Senior Java Software Engineer - Data Exchange',
#  'Senior Specialist - Data Architect within the ICT Department...',
#  'Technical Product Manager, Data',
#  'Traineeship Data',
#  'big data specialist']

# %% [markdown]
# ### Industry check-up

# %%
jobs.Industry.unique()
# Out:
# array(['Human resources en personeel', nan, 'Transport en vrachtvervoer',
#        'Consumentengoederen en dienstverlening',
#        'Consultancy en zakelijke dienstverlening',
#        'Banken en financiële dienstverlening', 'Detailhandel', 'Overheid',
#        'Gezondheidszorg', 'Internet en software', 'Landbouw en mijnbouw',
#        'Computers en elektronica', 'Telecommunicatie',
#        'OverheidConsultancy en zakelijke dienstverlening',
#        'Restaurants, reizen en vrije tijd', 'Farmaceutica',
#        'Onroerend goed', 'Energie en nutsbedrijven',
#        'Lucht- en ruimtevaartindustrie en defensie',
#        'Voedingsmiddelen en dranken',
#        'Human resources en personeelConsultancy en zakelijke dienstverlening',
#        'Maakindustrie', 'Verzekering'], dtype=object)

# %%
jobs[jobs['Industry'].isnull()].groupby('Company').count().sort_values(by='Title', ascending=False)
# Out:
#                                Title  Location  Salary  Since  Description  \
# Company
# CareerValue                       38        38      14     38            0
# MagnaVersum                        9         9       0      9            0
# Darwin Recruitment                 8         8       6      8            0
# Yacht                              6         6       0      6            0
# My Jewellery                       6         6       0      6            0
# ...                              ...       ...     ...    ...          ...
# KPI Solutions B.V.                 1         1       0      1            0
# Ipreo                              1         1       0      1            0
# International Travel Group         1         1       0      1            0
# Impact Information Management      1         1       0      1            0
# mySendle                           1         1       0      1            0
#
#                                Company Url  Industry  Company size  \
# Company
# CareerValue                             38         0             0
# MagnaVersum                              0         0             0
# Darwin Recruitment                       8         0             8
# Yacht                                    6         0             0
# My Jewellery                             0         0             0
# ...                                    ...       ...           ...
# KPI Solutions B.V.                       0         0             0
# Ipreo                                    0         0             0
# International Travel Group               0         0             0
# Impact Information Management            0         0             0
# mySendle                                 0         0             0
#
#                                Title Grouped
# Company
# CareerValue                               38
# MagnaVersum                                9
# Darwin Recruitment                         8
# Yacht                                      6
# My Jewellery                               6
# ...                                      ...
# KPI Solutions B.V.                         1
# Ipreo                                      1
# International Travel Group                 1
# Impact Information Management              1
# mySendle                                   1
#
# [160 rows x 9 columns]

# %% [markdown]
# ### Cleaning salary

# %%
min_salary = []
max_salary = []

for sal in jobs['Salary']:
    if type(sal) == str:
        sal = sal.split('-')
        sal_min = re.sub("[^0-9]", "", sal[0])
        if len(sal) == 2:
            sal_max = re.sub("[^0-9]", "", sal[1])
        else:
            sal_max = sal_min
                                               
    else:
        sal_min = 0
        sal_max = 0
    
    min_salary.append(sal_min)
    max_salary.append(sal_max)
    
jobs['Min Salary'] = min_salary
jobs['Max Salary'] = max_salary

jobs.replace(0, np.nan, inplace=True)

jobs['Min Salary'] = jobs['Min Salary'].astype(float)
jobs['Max Salary'] = jobs['Max Salary'].astype(float)

# %%
jobs.head(60)
# Out:
#                                                  Title             Location  \
# 0                                       Data Scientist             Den Haag
# 10             Director Business Analysis and Planning             Schiphol
# 14                       Chapter Lead Data Engineering               Diemen
# 15                                  Database Marketeer             Schiedam
# 17   Business Analyst with an Asset Management spec...              Utrecht
# 20                     Junior Data Analist Remediation               Diemen
# 21   Senior Data Engineer BI domein Commercie - Utr...   Utrecht Binnenstad
# 23                                        Data Analist            Dordrecht
# 24                                       Data Engineer            Amsterdam
# 25                                      Data Scientist            Amsterdam
# 26            Master Data Specialist / Jr Data Analyst            Amsterdam
# 27                Trainee Data Engineer | Lady Legends           Amersfoort
# 30                     Senior Data Analist Remediation               Diemen
# 31                               Data Scientist Medior            Rotterdam
# 35                                        Data Analist            Den Bosch
# 36                                 Data Science Intern       Amsterdam West
# 44                  Applicatiebeheerder / Data analist              Rijssen
# 48                       Chapter Lead Data Engineering               Diemen
# 50                                    Business Analyst              Utrecht
# 54                          Tech Lead Data Engineering               Diemen
# 64                          Tech Lead Data Engineering               Diemen
# 75                 Data Platform Product Owner (Azure)            Amsterdam
# 87                 Sr. Business Intelligence Developer              Utrecht
# 97                       HBO Meewerkstage Data Science           Amersfoort
# 111             Data Scientist Conversational AI (f/m)            Amsterdam
# 112            Business Intelligence Specialist | Tiel                 Tiel
# 113                                       Data Analist              Zaandam
# 114                                   Business Analist              Utrecht
# 115                         Business Intelligence Lead         Utrecht Oost
# 116            Business Intelligence (BI) professional            Veldhoven
# 117                       Business Analist (32-40 uur)         Nieuw-Vennep
# 118            Thesis Research - Business Intelligence       Amsterdam Zuid
# 119  Applied Data Scientist with a Data Engineering...       Amsterdam Zuid
# 122                                     Data Scientist            Amsterdam
# 125                                Senior Data-analist            Amsterdam
# 128          Data Science Development Program Den Haag             Den Haag
# 130                    Data Analyst / Reporting Expert         Utrecht Oost
# 132                                       Data Analyst            Hoofddorp
# 133                  Informatie Analist / Data Analist            Rotterdam
# 134  Data Partnerships & Outreach Manager, Climate ...             Den Haag
# 135  Data Partnerships & Outreach Manager, Climate ...             Den Haag
# 137                             Technisch Data Analist            Amsterdam
# 143                                   CRM Data Analyst            Hoofddorp
# 144                   Claims Technician / Data Analyst            Rotterdam
# 146          Machine Learning Engineer (junior/medior)                Delft
# 147                          Marketing Data Specialist  Rotterdam Overschie
# 149                                  Data & BI Analyst               Zwolle
# 151                      Data Analist/ETL ontwikkelaar           Leeuwarden
# 155                   Senior Machine Learning Engineer            Amsterdam
# 160                                     Data custodian   Utrecht Binnenstad
# 163                                   Business Analyst            Amsterdam
# 171                          Business analist (senior)            Amsterdam
# 173             Informatie Analist / Data Analist / BI    Rotterdam Centrum
# 178  PhD Position Deep Learning from Unlabelled Sen...                Delft
# 184                   Business Analist Ketenmonitoring            Apeldoorn
# 196       Big Data Specialist bij het Spaarne Gasthuis            Hoofddorp
# 201     Senior Business Analyst COORF Accounting Tribe            Amsterdam
# 203  PhD Position New Machine Learning Strategies f...                Delft
# 235                 Junior Strategy & Business Analyst             Doesburg
# 238            Ben jij de technische data consultant ?            Rotterdam
#
#                          Company                      Salary  \
# 0                           HAYS                         NaN
# 10                Liberty Global                         NaN
# 14                    Tempo-Team   €4.000 - €5.400 per maand
# 15   Lefit Recruitment & Interim                         NaN
# 17             De Staffing Groep                         NaN
# 20   International Card Services  €38.528 - €58.842 per jaar
# 21                            NS            €5.968 per maand
# 23            Regio Drechtsteden            €4.450 per maand
# 24                  True Legends   €3.250 - €4.250 per maand
# 25            Darwin Recruitment                         NaN
# 26                Tommy Hilfiger                         NaN
# 27                  True Legends   €2.750 - €3.250 per maand
# 30   International Card Services  €49.712 - €76.356 per jaar
# 31                           Aon   €3.800 - €4.800 per maand
# 35                           SMQ                         NaN
# 36                   Dealroom.co                         NaN
# 44                      Artiflex   €2.800 - €3.800 per maand
# 48      Randstad Groep Nederland   €4.000 - €5.400 per maand
# 50      Double Match Recruitment                         NaN
# 54      Randstad Groep Nederland   €4.000 - €5.406 per maand
# 64                    Tempo-Team   €4.000 - €5.406 per maand
# 75                    FixedToday                         NaN
# 87                      Rabobank                         NaN
# 97             Morgana Nederland                         NaN
# 111                ABN AMRO Bank  €60.000 - €75.000 per jaar
# 112               Santé Partners   €3.196 - €4.744 per maand
# 113                 Albert Heijn                         NaN
# 114                     Rabobank   €3.677 - €5.252 per maand
# 115            Digital Decisions                         NaN
# 116               Stichting PAMM            €4.682 per maand
# 117                 Korton Group                         NaN
# 118                        felyx                         NaN
# 119                        Owlin                         NaN
# 122                         OMRT                         NaN
# 125           Gemeente Amsterdam   €3.526 - €5.118 per maand
# 128                        Aegon                         NaN
# 130            Digital Decisions                         NaN
# 132                    Basic-Fit                         NaN
# 133                       iSense   €3.500 - €4.500 per maand
# 134    World Resources Institute                         NaN
# 135    World Resources Institute                         NaN
# 137       Independent Recruiters   €2.500 - €4.500 per maand
# 143                Scotch & Soda                         NaN
# 144                     MS Amlin                         NaN
# 146      Mobile Water Management                         NaN
# 147         The Little Green Bag                         NaN
# 149                        Wavin                         NaN
# 151                    Ormer ICT                         NaN
# 155                   DAZN Group                         NaN
# 160              Belastingdienst                         NaN
# 163                       Hiscox                         NaN
# 171                       LINKIT                         NaN
# 173                       iSense   €3.500 - €5.000 per maand
# 178                     TU Delft            €2.395 per maand
# 184                   FixedToday                         NaN
# 196           Lectio Recruitment            €4.682 per maand
# 201                          ING                         NaN
# 203                     TU Delft            €2.395 per maand
# 235     Ubbink Centrotherm Group                         NaN
# 238                  CareerValue                         NaN
#
#                  Since  Description                       Company Url  \
# 0        Net geplaatst          NaN                         /cmp/Hays
# 10   Vandaag geplaatst          NaN               /cmp/Liberty-Global
# 14   Vandaag geplaatst          NaN                  /cmp/Tempo--team
# 15   Vandaag geplaatst          NaN                               NaN
# 17   Vandaag geplaatst          NaN            /cmp/De-Staffing-Groep
# 20   Vandaag geplaatst          NaN  /cmp/International-Card-Services
# 21   Vandaag geplaatst          NaN                           /cmp/Ns
# 23   Vandaag geplaatst          NaN                               NaN
# 24   Vandaag geplaatst          NaN                 /cmp/True-Legends
# 25   Vandaag geplaatst          NaN           /cmp/Darwin-Recruitment
# 26   Vandaag geplaatst          NaN               /cmp/Tommy-Hilfiger
# 27   Vandaag geplaatst          NaN                 /cmp/True-Legends
# 30   Vandaag geplaatst          NaN  /cmp/International-Card-Services
# 31   Vandaag geplaatst          NaN                          /cmp/Aon
# 35   Vandaag geplaatst          NaN                               NaN
# 36   Vandaag geplaatst          NaN                               NaN
# 44   Vandaag geplaatst          NaN                     /cmp/Artiflex
# 48   Vandaag geplaatst          NaN     /cmp/Randstad-Groep-Nederland
# 50   Vandaag geplaatst          NaN                               NaN
# 54   Vandaag geplaatst          NaN     /cmp/Randstad-Groep-Nederland
# 64   Vandaag geplaatst          NaN                  /cmp/Tempo--team
# 75   Vandaag geplaatst          NaN                               NaN
# 87   Vandaag geplaatst          NaN                     /cmp/Rabobank
# 97   Vandaag geplaatst          NaN                               NaN
# 111      1 dag geleden          NaN                     /cmp/Abn-Amro
# 112      1 dag geleden          NaN                               NaN
# 113      1 dag geleden          NaN                 /cmp/Albert-Heijn
# 114      1 dag geleden          NaN                     /cmp/Rabobank
# 115      1 dag geleden          NaN                               NaN
# 116      1 dag geleden          NaN                               NaN
# 117      1 dag geleden          NaN                               NaN
# 118      1 dag geleden          NaN                               NaN
# 119      1 dag geleden          NaN                               NaN
# 122      1 dag geleden          NaN                               NaN
# 125      1 dag geleden          NaN           /cmp/Gemeente-Amsterdam
# 128      1 dag geleden          NaN                        /cmp/Aegon
# 130      1 dag geleden          NaN                               NaN
# 132      1 dag geleden          NaN                   /cmp/Basic--fit
# 133      1 dag geleden          NaN                       /cmp/Isense
# 134      1 dag geleden          NaN                               NaN
# 135      1 dag geleden          NaN                               NaN
# 137      1 dag geleden          NaN       /cmp/Independent-Recruiters
# 143      1 dag geleden          NaN                /cmp/Scotch-&-Soda
# 144      1 dag geleden          NaN                               NaN
# 146      1 dag geleden          NaN                               NaN
# 147      1 dag geleden          NaN                               NaN
# 149      1 dag geleden          NaN                        /cmp/Wavin
# 151      1 dag geleden          NaN                               NaN
# 155      1 dag geleden          NaN                               NaN
# 160      1 dag geleden          NaN              /cmp/Belastingdienst
# 163      1 dag geleden          NaN                               NaN
# 171      1 dag geleden          NaN                       /cmp/Linkit
# 173      1 dag geleden          NaN                       /cmp/Isense
# 178      1 dag geleden          NaN                     /cmp/Tu-Delft
# 184      1 dag geleden          NaN                               NaN
# 196      1 dag geleden          NaN                               NaN
# 201      1 dag geleden          NaN                          /cmp/Ing
# 203      1 dag geleden          NaN                     /cmp/Tu-Delft
# 235      1 dag geleden          NaN                               NaN
# 238      1 dag geleden          NaN                  /cmp/Careervalue
#
#                                      Industry      Company size  \
# 0                Human resources en personeel  5.001 tot 10.000
# 10                                        NaN   Meer dan 10.000
# 14               Human resources en personeel   1.001 tot 5.000
# 15                                        NaN               NaN
# 17                                        NaN               NaN
# 20                                        NaN       201 tot 500
# 21                 Transport en vrachtvervoer   Meer dan 10.000
# 23                                        NaN               NaN
# 24               Human resources en personeel        51 tot 200
# 25                                        NaN        51 tot 200
# 26     Consumentengoederen en dienstverlening   Meer dan 10.000
# 27               Human resources en personeel        51 tot 200
# 30                                        NaN       201 tot 500
# 31   Consultancy en zakelijke dienstverlening   Meer dan 10.000
# 35                                        NaN               NaN
# 36                                        NaN               NaN
# 44               Human resources en personeel     501 tot 1.000
# 48                                        NaN               NaN
# 50                                        NaN               NaN
# 54                                        NaN               NaN
# 64               Human resources en personeel   1.001 tot 5.000
# 75                                        NaN               NaN
# 87       Banken en financiële dienstverlening   Meer dan 10.000
# 97                                        NaN               NaN
# 111      Banken en financiële dienstverlening   Meer dan 10.000
# 112                                       NaN               NaN
# 113                              Detailhandel   Meer dan 10.000
# 114      Banken en financiële dienstverlening   Meer dan 10.000
# 115                                       NaN               NaN
# 116                                       NaN               NaN
# 117                                       NaN               NaN
# 118                                       NaN               NaN
# 119                                       NaN               NaN
# 122                                       NaN               NaN
# 125                                  Overheid               NaN
# 128      Banken en financiële dienstverlening   Meer dan 10.000
# 130                                       NaN               NaN
# 132    Consumentengoederen en dienstverlening   1.001 tot 5.000
# 133  Consultancy en zakelijke dienstverlening        51 tot 200
# 134                                       NaN               NaN
# 135                                       NaN               NaN
# 137              Human resources en personeel         11 tot 50
# 143    Consumentengoederen en dienstverlening   1.001 tot 5.000
# 144                                       NaN               NaN
# 146                                       NaN               NaN
# 147                                       NaN               NaN
# 149                                       NaN  5.001 tot 10.000
# 151                                       NaN               NaN
# 155                                       NaN               NaN
# 160                                  Overheid   Meer dan 10.000
# 163                                       NaN               NaN
# 171  Consultancy en zakelijke dienstverlening     501 tot 1.000
# 173  Consultancy en zakelijke dienstverlening        51 tot 200
# 178                                       NaN               NaN
# 184                                       NaN               NaN
# 196                                       NaN               NaN
# 201      Banken en financiële dienstverlening   Meer dan 10.000
# 203                                       NaN               NaN
# 235                                       NaN               NaN
# 238                                       NaN               NaN
#
#                                  Title Grouped  Min Salary  Max Salary
# 0                               Data Scientist         NaN         NaN
# 10                            Business Analyst         NaN         NaN
# 14                               Data Engineer      4000.0      5400.0
# 15                                       Other         NaN         NaN
# 17                            Business Analyst         NaN         NaN
# 20                                Data Analyst     38528.0     58842.0
# 21                               Data Engineer      5968.0      5968.0
# 23                                Data Analyst      4450.0      4450.0
# 24                               Data Engineer      3250.0      4250.0
# 25                              Data Scientist         NaN         NaN
# 26                                Data Analyst         NaN         NaN
# 27                               Data Engineer      2750.0      3250.0
# 30                                Data Analyst     49712.0     76356.0
# 31                              Data Scientist      3800.0      4800.0
# 35                                Data Analyst         NaN         NaN
# 36                              Data Scientist         NaN         NaN
# 44                                Data Analyst      2800.0      3800.0
# 48                               Data Engineer      4000.0      5400.0
# 50                            Business Analyst         NaN         NaN
# 54                               Data Engineer      4000.0      5406.0
# 64                               Data Engineer      4000.0      5406.0
# 75                                       Other         NaN         NaN
# 87   Business Intelligence Consultant/Engineer         NaN         NaN
# 97                              Data Scientist         NaN         NaN
# 111                             Data Scientist     60000.0     75000.0
# 112  Business Intelligence Consultant/Engineer      3196.0      4744.0
# 113                               Data Analyst         NaN         NaN
# 114                           Business Analyst      3677.0      5252.0
# 115  Business Intelligence Consultant/Engineer         NaN         NaN
# 116  Business Intelligence Consultant/Engineer      4682.0      4682.0
# 117                           Business Analyst         NaN         NaN
# 118  Business Intelligence Consultant/Engineer         NaN         NaN
# 119                             Data Scientist         NaN         NaN
# 122                             Data Scientist         NaN         NaN
# 125                               Data Analyst      3526.0      5118.0
# 128                             Data Scientist         NaN         NaN
# 130                               Data Analyst         NaN         NaN
# 132                               Data Analyst         NaN         NaN
# 133                               Data Analyst      3500.0      4500.0
# 134                                      Other         NaN         NaN
# 135                                      Other         NaN         NaN
# 137                               Data Analyst      2500.0      4500.0
# 143                               Data Analyst         NaN         NaN
# 144                               Data Analyst         NaN         NaN
# 146                              Data Engineer         NaN         NaN
# 147                                      Other         NaN         NaN
# 149                               Data Analyst         NaN         NaN
# 151                               Data Analyst         NaN         NaN
# 155                              Data Engineer         NaN         NaN
# 160                                      Other         NaN         NaN
# 163                           Business Analyst         NaN         NaN
# 171                           Business Analyst         NaN         NaN
# 173                               Data Analyst      3500.0      5000.0
# 178                                      Other      2395.0      2395.0
# 184                           Business Analyst         NaN         NaN
# 196                                      Other      4682.0      4682.0
# 201                           Business Analyst         NaN         NaN
# 203                                      Other      2395.0      2395.0
# 235                           Business Analyst         NaN         NaN
# 238                       Analytics Consultant         NaN         NaN

# %%
jobs.dtypes
# Out:
# Title             object
# Location          object
# Company           object
# Salary            object
# Since             object
# Description      float64
# Company Url       object
# Industry          object
# Company size      object
# Title Grouped     object
# Min Salary       float64
# Max Salary       float64
# dtype: object

# %%
def sal_type(x):
    try:
        if re.search('maand', x):
            saltype = 'Monthly'
        elif re.search('jaar', x):
            saltype = 'Annual'
        elif re.search('uur', x):
            saltype = 'Hourly'
        elif re.search('week', x):
            saltype='Weekly'
        return saltype
    except:
        saltype = 'Not Specified'
 
        return saltype

# %%
jobs['Salary Type'] = jobs['Salary'].apply(lambda x: sal_type(x))

# %%
jobs['Salary Type'].value_counts()
# Out:
# Not Specified    297
# Monthly           94
# Annual            18
# Hourly             3
# Weekly             1
# Name: Salary Type, dtype: int64

# %%
def norm_salary(x):
    salary_min = 0
    salary_max = 0
    if x['Salary Type'] == 'Annual':
        salary_min = x['Min Salary']/12
        salary_max = x['Max Salary']/12
    elif x['Salary Type'] == 'Hourly':
        salary_min = x['Min Salary']*160
        salary_max = x['Min Salary']*160
    elif x['Salary Type'] == 'Monthly':
        salary_min = x['Min Salary']
        salary_max = x['Max Salary']
    elif x['Salary Type'] == 'Weekly':
        salary_min = x['Min Salary']*4
        salary_max = x['Min Salary']*4
    return salary_min, salary_max

# %%
jobs['Normalized Sal Min'] = jobs.apply(lambda x: norm_salary(x)[0], axis=1)
jobs['Normalized Sal Max'] = jobs.apply(lambda x: norm_salary(x)[1], axis=1)
jobs['Normalized Sal Avg'] = (jobs['Normalized Sal Min']+jobs['Normalized Sal Max'])/2

# %% [markdown]
# #### Cleaning Days since posted

# %%
jobs.Since.value_counts()
# Out:
# Meer dan 30 dagen geleden    99
# 1 dag geleden                36
# 2 dagen geleden              36
# 9 dagen geleden              30
# 12 dagen geleden             26
# 5 dagen geleden              26
# 7 dagen geleden              25
# 8 dagen geleden              25
# Vandaag geplaatst            23
# 6 dagen geleden              19
# 20 dagen geleden             16
# 13 dagen geleden             11
# 15 dagen geleden              9
# 19 dagen geleden              8
# 14 dagen geleden              7
# 16 dagen geleden              5
# 21 dagen geleden              3
# 11 dagen geleden              2
# 27 dagen geleden              1
# 4 dagen geleden               1
# 17 dagen geleden              1
# 29 dagen geleden              1
# 18 dagen geleden              1
# 22 dagen geleden              1
# Net geplaatst                 1
# Name: Since, dtype: int64

# %%
# 


def posted_days(x):
    if x in ['Vandaag geplaatst', 'Net geplaatst']:
        x = 0
    else:
        x = re.sub('[^0-9]', "", x)
        if x == '':
            x = np.nan
    return x 

def posted(x):
    if x <= 7:
        y='This week'
    elif x <= 20:
        y= '2 weeks ago'
    elif x < 27:
        y= '3 weeks ago'
    else:
        y= 'More than 4 weeks ago'
    return y

jobs['Posted_days'] = jobs['Since'].apply(lambda x: posted_days(x))
jobs['Posted_days'] = jobs['Posted_days'].astype(float)
jobs['Posted'] = jobs['Posted_days'].apply(lambda x: posted(x))

# %%
jobs.head(60)
# Out:
#                                                  Title             Location  \
# 0                                       Data Scientist             Den Haag
# 10             Director Business Analysis and Planning             Schiphol
# 14                       Chapter Lead Data Engineering               Diemen
# 15                                  Database Marketeer             Schiedam
# 17   Business Analyst with an Asset Management spec...              Utrecht
# 20                     Junior Data Analist Remediation               Diemen
# 21   Senior Data Engineer BI domein Commercie - Utr...   Utrecht Binnenstad
# 23                                        Data Analist            Dordrecht
# 24                                       Data Engineer            Amsterdam
# 25                                      Data Scientist            Amsterdam
# 26            Master Data Specialist / Jr Data Analyst            Amsterdam
# 27                Trainee Data Engineer | Lady Legends           Amersfoort
# 30                     Senior Data Analist Remediation               Diemen
# 31                               Data Scientist Medior            Rotterdam
# 35                                        Data Analist            Den Bosch
# 36                                 Data Science Intern       Amsterdam West
# 44                  Applicatiebeheerder / Data analist              Rijssen
# 48                       Chapter Lead Data Engineering               Diemen
# 50                                    Business Analyst              Utrecht
# 54                          Tech Lead Data Engineering               Diemen
# 64                          Tech Lead Data Engineering               Diemen
# 75                 Data Platform Product Owner (Azure)            Amsterdam
# 87                 Sr. Business Intelligence Developer              Utrecht
# 97                       HBO Meewerkstage Data Science           Amersfoort
# 111             Data Scientist Conversational AI (f/m)            Amsterdam
# 112            Business Intelligence Specialist | Tiel                 Tiel
# 113                                       Data Analist              Zaandam
# 114                                   Business Analist              Utrecht
# 115                         Business Intelligence Lead         Utrecht Oost
# 116            Business Intelligence (BI) professional            Veldhoven
# 117                       Business Analist (32-40 uur)         Nieuw-Vennep
# 118            Thesis Research - Business Intelligence       Amsterdam Zuid
# 119  Applied Data Scientist with a Data Engineering...       Amsterdam Zuid
# 122                                     Data Scientist            Amsterdam
# 125                                Senior Data-analist            Amsterdam
# 128          Data Science Development Program Den Haag             Den Haag
# 130                    Data Analyst / Reporting Expert         Utrecht Oost
# 132                                       Data Analyst            Hoofddorp
# 133                  Informatie Analist / Data Analist            Rotterdam
# 134  Data Partnerships & Outreach Manager, Climate ...             Den Haag
# 135  Data Partnerships & Outreach Manager, Climate ...             Den Haag
# 137                             Technisch Data Analist            Amsterdam
# 143                                   CRM Data Analyst            Hoofddorp
# 144                   Claims Technician / Data Analyst            Rotterdam
# 146          Machine Learning Engineer (junior/medior)                Delft
# 147                          Marketing Data Specialist  Rotterdam Overschie
# 149                                  Data & BI Analyst               Zwolle
# 151                      Data Analist/ETL ontwikkelaar           Leeuwarden
# 155                   Senior Machine Learning Engineer            Amsterdam
# 160                                     Data custodian   Utrecht Binnenstad
# 163                                   Business Analyst            Amsterdam
# 171                          Business analist (senior)            Amsterdam
# 173             Informatie Analist / Data Analist / BI    Rotterdam Centrum
# 178  PhD Position Deep Learning from Unlabelled Sen...                Delft
# 184                   Business Analist Ketenmonitoring            Apeldoorn
# 196       Big Data Specialist bij het Spaarne Gasthuis            Hoofddorp
# 201     Senior Business Analyst COORF Accounting Tribe            Amsterdam
# 203  PhD Position New Machine Learning Strategies f...                Delft
# 235                 Junior Strategy & Business Analyst             Doesburg
# 238            Ben jij de technische data consultant ?            Rotterdam
#
#                          Company                      Salary  \
# 0                           HAYS                         NaN
# 10                Liberty Global                         NaN
# 14                    Tempo-Team   €4.000 - €5.400 per maand
# 15   Lefit Recruitment & Interim                         NaN
# 17             De Staffing Groep                         NaN
# 20   International Card Services  €38.528 - €58.842 per jaar
# 21                            NS            €5.968 per maand
# 23            Regio Drechtsteden            €4.450 per maand
# 24                  True Legends   €3.250 - €4.250 per maand
# 25            Darwin Recruitment                         NaN
# 26                Tommy Hilfiger                         NaN
# 27                  True Legends   €2.750 - €3.250 per maand
# 30   International Card Services  €49.712 - €76.356 per jaar
# 31                           Aon   €3.800 - €4.800 per maand
# 35                           SMQ                         NaN
# 36                   Dealroom.co                         NaN
# 44                      Artiflex   €2.800 - €3.800 per maand
# 48      Randstad Groep Nederland   €4.000 - €5.400 per maand
# 50      Double Match Recruitment                         NaN
# 54      Randstad Groep Nederland   €4.000 - €5.406 per maand
# 64                    Tempo-Team   €4.000 - €5.406 per maand
# 75                    FixedToday                         NaN
# 87                      Rabobank                         NaN
# 97             Morgana Nederland                         NaN
# 111                ABN AMRO Bank  €60.000 - €75.000 per jaar
# 112               Santé Partners   €3.196 - €4.744 per maand
# 113                 Albert Heijn                         NaN
# 114                     Rabobank   €3.677 - €5.252 per maand
# 115            Digital Decisions                         NaN
# 116               Stichting PAMM            €4.682 per maand
# 117                 Korton Group                         NaN
# 118                        felyx                         NaN
# 119                        Owlin                         NaN
# 122                         OMRT                         NaN
# 125           Gemeente Amsterdam   €3.526 - €5.118 per maand
# 128                        Aegon                         NaN
# 130            Digital Decisions                         NaN
# 132                    Basic-Fit                         NaN
# 133                       iSense   €3.500 - €4.500 per maand
# 134    World Resources Institute                         NaN
# 135    World Resources Institute                         NaN
# 137       Independent Recruiters   €2.500 - €4.500 per maand
# 143                Scotch & Soda                         NaN
# 144                     MS Amlin                         NaN
# 146      Mobile Water Management                         NaN
# 147         The Little Green Bag                         NaN
# 149                        Wavin                         NaN
# 151                    Ormer ICT                         NaN
# 155                   DAZN Group                         NaN
# 160              Belastingdienst                         NaN
# 163                       Hiscox                         NaN
# 171                       LINKIT                         NaN
# 173                       iSense   €3.500 - €5.000 per maand
# 178                     TU Delft            €2.395 per maand
# 184                   FixedToday                         NaN
# 196           Lectio Recruitment            €4.682 per maand
# 201                          ING                         NaN
# 203                     TU Delft            €2.395 per maand
# 235     Ubbink Centrotherm Group                         NaN
# 238                  CareerValue                         NaN
#
#                  Since  Description                       Company Url  \
# 0        Net geplaatst          NaN                         /cmp/Hays
# 10   Vandaag geplaatst          NaN               /cmp/Liberty-Global
# 14   Vandaag geplaatst          NaN                  /cmp/Tempo--team
# 15   Vandaag geplaatst          NaN                               NaN
# 17   Vandaag geplaatst          NaN            /cmp/De-Staffing-Groep
# 20   Vandaag geplaatst          NaN  /cmp/International-Card-Services
# 21   Vandaag geplaatst          NaN                           /cmp/Ns
# 23   Vandaag geplaatst          NaN                               NaN
# 24   Vandaag geplaatst          NaN                 /cmp/True-Legends
# 25   Vandaag geplaatst          NaN           /cmp/Darwin-Recruitment
# 26   Vandaag geplaatst          NaN               /cmp/Tommy-Hilfiger
# 27   Vandaag geplaatst          NaN                 /cmp/True-Legends
# 30   Vandaag geplaatst          NaN  /cmp/International-Card-Services
# 31   Vandaag geplaatst          NaN                          /cmp/Aon
# 35   Vandaag geplaatst          NaN                               NaN
# 36   Vandaag geplaatst          NaN                               NaN
# 44   Vandaag geplaatst          NaN                     /cmp/Artiflex
# 48   Vandaag geplaatst          NaN     /cmp/Randstad-Groep-Nederland
# 50   Vandaag geplaatst          NaN                               NaN
# 54   Vandaag geplaatst          NaN     /cmp/Randstad-Groep-Nederland
# 64   Vandaag geplaatst          NaN                  /cmp/Tempo--team
# 75   Vandaag geplaatst          NaN                               NaN
# 87   Vandaag geplaatst          NaN                     /cmp/Rabobank
# 97   Vandaag geplaatst          NaN                               NaN
# 111      1 dag geleden          NaN                     /cmp/Abn-Amro
# 112      1 dag geleden          NaN                               NaN
# 113      1 dag geleden          NaN                 /cmp/Albert-Heijn
# 114      1 dag geleden          NaN                     /cmp/Rabobank
# 115      1 dag geleden          NaN                               NaN
# 116      1 dag geleden          NaN                               NaN
# 117      1 dag geleden          NaN                               NaN
# 118      1 dag geleden          NaN                               NaN
# 119      1 dag geleden          NaN                               NaN
# 122      1 dag geleden          NaN                               NaN
# 125      1 dag geleden          NaN           /cmp/Gemeente-Amsterdam
# 128      1 dag geleden          NaN                        /cmp/Aegon
# 130      1 dag geleden          NaN                               NaN
# 132      1 dag geleden          NaN                   /cmp/Basic--fit
# 133      1 dag geleden          NaN                       /cmp/Isense
# 134      1 dag geleden          NaN                               NaN
# 135      1 dag geleden          NaN                               NaN
# 137      1 dag geleden          NaN       /cmp/Independent-Recruiters
# 143      1 dag geleden          NaN                /cmp/Scotch-&-Soda
# 144      1 dag geleden          NaN                               NaN
# 146      1 dag geleden          NaN                               NaN
# 147      1 dag geleden          NaN                               NaN
# 149      1 dag geleden          NaN                        /cmp/Wavin
# 151      1 dag geleden          NaN                               NaN
# 155      1 dag geleden          NaN                               NaN
# 160      1 dag geleden          NaN              /cmp/Belastingdienst
# 163      1 dag geleden          NaN                               NaN
# 171      1 dag geleden          NaN                       /cmp/Linkit
# 173      1 dag geleden          NaN                       /cmp/Isense
# 178      1 dag geleden          NaN                     /cmp/Tu-Delft
# 184      1 dag geleden          NaN                               NaN
# 196      1 dag geleden          NaN                               NaN
# 201      1 dag geleden          NaN                          /cmp/Ing
# 203      1 dag geleden          NaN                     /cmp/Tu-Delft
# 235      1 dag geleden          NaN                               NaN
# 238      1 dag geleden          NaN                  /cmp/Careervalue
#
#                                      Industry      Company size  \
# 0                Human resources en personeel  5.001 tot 10.000
# 10                                        NaN   Meer dan 10.000
# 14               Human resources en personeel   1.001 tot 5.000
# 15                                        NaN               NaN
# 17                                        NaN               NaN
# 20                                        NaN       201 tot 500
# 21                 Transport en vrachtvervoer   Meer dan 10.000
# 23                                        NaN               NaN
# 24               Human resources en personeel        51 tot 200
# 25                                        NaN        51 tot 200
# 26     Consumentengoederen en dienstverlening   Meer dan 10.000
# 27               Human resources en personeel        51 tot 200
# 30                                        NaN       201 tot 500
# 31   Consultancy en zakelijke dienstverlening   Meer dan 10.000
# 35                                        NaN               NaN
# 36                                        NaN               NaN
# 44               Human resources en personeel     501 tot 1.000
# 48                                        NaN               NaN
# 50                                        NaN               NaN
# 54                                        NaN               NaN
# 64               Human resources en personeel   1.001 tot 5.000
# 75                                        NaN               NaN
# 87       Banken en financiële dienstverlening   Meer dan 10.000
# 97                                        NaN               NaN
# 111      Banken en financiële dienstverlening   Meer dan 10.000
# 112                                       NaN               NaN
# 113                              Detailhandel   Meer dan 10.000
# 114      Banken en financiële dienstverlening   Meer dan 10.000
# 115                                       NaN               NaN
# 116                                       NaN               NaN
# 117                                       NaN               NaN
# 118                                       NaN               NaN
# 119                                       NaN               NaN
# 122                                       NaN               NaN
# 125                                  Overheid               NaN
# 128      Banken en financiële dienstverlening   Meer dan 10.000
# 130                                       NaN               NaN
# 132    Consumentengoederen en dienstverlening   1.001 tot 5.000
# 133  Consultancy en zakelijke dienstverlening        51 tot 200
# 134                                       NaN               NaN
# 135                                       NaN               NaN
# 137              Human resources en personeel         11 tot 50
# 143    Consumentengoederen en dienstverlening   1.001 tot 5.000
# 144                                       NaN               NaN
# 146                                       NaN               NaN
# 147                                       NaN               NaN
# 149                                       NaN  5.001 tot 10.000
# 151                                       NaN               NaN
# 155                                       NaN               NaN
# 160                                  Overheid   Meer dan 10.000
# 163                                       NaN               NaN
# 171  Consultancy en zakelijke dienstverlening     501 tot 1.000
# 173  Consultancy en zakelijke dienstverlening        51 tot 200
# 178                                       NaN               NaN
# 184                                       NaN               NaN
# 196                                       NaN               NaN
# 201      Banken en financiële dienstverlening   Meer dan 10.000
# 203                                       NaN               NaN
# 235                                       NaN               NaN
# 238                                       NaN               NaN
#
#                                  Title Grouped  Min Salary  Max Salary  \
# 0                               Data Scientist         NaN         NaN
# 10                            Business Analyst         NaN         NaN
# 14                               Data Engineer      4000.0      5400.0
# 15                                       Other         NaN         NaN
# 17                            Business Analyst         NaN         NaN
# 20                                Data Analyst     38528.0     58842.0
# 21                               Data Engineer      5968.0      5968.0
# 23                                Data Analyst      4450.0      4450.0
# 24                               Data Engineer      3250.0      4250.0
# 25                              Data Scientist         NaN         NaN
# 26                                Data Analyst         NaN         NaN
# 27                               Data Engineer      2750.0      3250.0
# 30                                Data Analyst     49712.0     76356.0
# 31                              Data Scientist      3800.0      4800.0
# 35                                Data Analyst         NaN         NaN
# 36                              Data Scientist         NaN         NaN
# 44                                Data Analyst      2800.0      3800.0
# 48                               Data Engineer      4000.0      5400.0
# 50                            Business Analyst         NaN         NaN
# 54                               Data Engineer      4000.0      5406.0
# 64                               Data Engineer      4000.0      5406.0
# 75                                       Other         NaN         NaN
# 87   Business Intelligence Consultant/Engineer         NaN         NaN
# 97                              Data Scientist         NaN         NaN
# 111                             Data Scientist     60000.0     75000.0
# 112  Business Intelligence Consultant/Engineer      3196.0      4744.0
# 113                               Data Analyst         NaN         NaN
# 114                           Business Analyst      3677.0      5252.0
# 115  Business Intelligence Consultant/Engineer         NaN         NaN
# 116  Business Intelligence Consultant/Engineer      4682.0      4682.0
# 117                           Business Analyst         NaN         NaN
# 118  Business Intelligence Consultant/Engineer         NaN         NaN
# 119                             Data Scientist         NaN         NaN
# 122                             Data Scientist         NaN         NaN
# 125                               Data Analyst      3526.0      5118.0
# 128                             Data Scientist         NaN         NaN
# 130                               Data Analyst         NaN         NaN
# 132                               Data Analyst         NaN         NaN
# 133                               Data Analyst      3500.0      4500.0
# 134                                      Other         NaN         NaN
# 135                                      Other         NaN         NaN
# 137                               Data Analyst      2500.0      4500.0
# 143                               Data Analyst         NaN         NaN
# 144                               Data Analyst         NaN         NaN
# 146                              Data Engineer         NaN         NaN
# 147                                      Other         NaN         NaN
# 149                               Data Analyst         NaN         NaN
# 151                               Data Analyst         NaN         NaN
# 155                              Data Engineer         NaN         NaN
# 160                                      Other         NaN         NaN
# 163                           Business Analyst         NaN         NaN
# 171                           Business Analyst         NaN         NaN
# 173                               Data Analyst      3500.0      5000.0
# 178                                      Other      2395.0      2395.0
# 184                           Business Analyst         NaN         NaN
# 196                                      Other      4682.0      4682.0
# 201                           Business Analyst         NaN         NaN
# 203                                      Other      2395.0      2395.0
# 235                           Business Analyst         NaN         NaN
# 238                       Analytics Consultant         NaN         NaN
#
#        Salary Type  Normalized Sal Min  Normalized Sal Max  \
# 0    Not Specified            0.000000                 0.0
# 10   Not Specified            0.000000                 0.0
# 14         Monthly         4000.000000              5400.0
# 15   Not Specified            0.000000                 0.0
# 17   Not Specified            0.000000                 0.0
# 20          Annual         3210.666667              4903.5
# 21         Monthly         5968.000000              5968.0
# 23         Monthly         4450.000000              4450.0
# 24         Monthly         3250.000000              4250.0
# 25   Not Specified            0.000000                 0.0
# 26   Not Specified            0.000000                 0.0
# 27         Monthly         2750.000000              3250.0
# 30          Annual         4142.666667              6363.0
# 31         Monthly         3800.000000              4800.0
# 35   Not Specified            0.000000                 0.0
# 36   Not Specified            0.000000                 0.0
# 44         Monthly         2800.000000              3800.0
# 48         Monthly         4000.000000              5400.0
# 50   Not Specified            0.000000                 0.0
# 54         Monthly         4000.000000              5406.0
# 64         Monthly         4000.000000              5406.0
# 75   Not Specified            0.000000                 0.0
# 87   Not Specified            0.000000                 0.0
# 97   Not Specified            0.000000                 0.0
# 111         Annual         5000.000000              6250.0
# 112        Monthly         3196.000000              4744.0
# 113  Not Specified            0.000000                 0.0
# 114        Monthly         3677.000000              5252.0
# 115  Not Specified            0.000000                 0.0
# 116        Monthly         4682.000000              4682.0
# 117  Not Specified            0.000000                 0.0
# 118  Not Specified            0.000000                 0.0
# 119  Not Specified            0.000000                 0.0
# 122  Not Specified            0.000000                 0.0
# 125        Monthly         3526.000000              5118.0
# 128  Not Specified            0.000000                 0.0
# 130  Not Specified            0.000000                 0.0
# 132  Not Specified            0.000000                 0.0
# 133        Monthly         3500.000000              4500.0
# 134  Not Specified            0.000000                 0.0
# 135  Not Specified            0.000000                 0.0
# 137        Monthly         2500.000000              4500.0
# 143  Not Specified            0.000000                 0.0
# 144  Not Specified            0.000000                 0.0
# 146  Not Specified            0.000000                 0.0
# 147  Not Specified            0.000000                 0.0
# 149  Not Specified            0.000000                 0.0
# 151  Not Specified            0.000000                 0.0
# 155  Not Specified            0.000000                 0.0
# 160  Not Specified            0.000000                 0.0
# 163  Not Specified            0.000000                 0.0
# 171  Not Specified            0.000000                 0.0
# 173        Monthly         3500.000000              5000.0
# 178        Monthly         2395.000000              2395.0
# 184  Not Specified            0.000000                 0.0
# 196        Monthly         4682.000000              4682.0
# 201  Not Specified            0.000000                 0.0
# 203        Monthly         2395.000000              2395.0
# 235  Not Specified            0.000000                 0.0
# 238  Not Specified            0.000000                 0.0
#
#      Normalized Sal Avg  Posted_days     Posted
# 0              0.000000          0.0  This week
# 10             0.000000          0.0  This week
# 14          4700.000000          0.0  This week
# 15             0.000000          0.0  This week
# 17             0.000000          0.0  This week
# 20          4057.083333          0.0  This week
# 21          5968.000000          0.0  This week
# 23          4450.000000          0.0  This week
# 24          3750.000000          0.0  This week
# 25             0.000000          0.0  This week
# 26             0.000000          0.0  This week
# 27          3000.000000          0.0  This week
# 30          5252.833333          0.0  This week
# 31          4300.000000          0.0  This week
# 35             0.000000          0.0  This week
# 36             0.000000          0.0  This week
# 44          3300.000000          0.0  This week
# 48          4700.000000          0.0  This week
# 50             0.000000          0.0  This week
# 54          4703.000000          0.0  This week
# 64          4703.000000          0.0  This week
# 75             0.000000          0.0  This week
# 87             0.000000          0.0  This week
# 97             0.000000          0.0  This week
# 111         5625.000000          1.0  This week
# 112         3970.000000          1.0  This week
# 113            0.000000          1.0  This week
# 114         4464.500000          1.0  This week
# 115            0.000000          1.0  This week
# 116         4682.000000          1.0  This week
# 117            0.000000          1.0  This week
# 118            0.000000          1.0  This week
# 119            0.000000          1.0  This week
# 122            0.000000          1.0  This week
# 125         4322.000000          1.0  This week
# 128            0.000000          1.0  This week
# 130            0.000000          1.0  This week
# 132            0.000000          1.0  This week
# 133         4000.000000          1.0  This week
# 134            0.000000          1.0  This week
# 135            0.000000          1.0  This week
# 137         3500.000000          1.0  This week
# 143            0.000000          1.0  This week
# 144            0.000000          1.0  This week
# 146            0.000000          1.0  This week
# 147            0.000000          1.0  This week
# 149            0.000000          1.0  This week
# 151            0.000000          1.0  This week
# 155            0.000000          1.0  This week
# 160            0.000000          1.0  This week
# 163            0.000000          1.0  This week
# 171            0.000000          1.0  This week
# 173         4250.000000          1.0  This week
# 178         2395.000000          1.0  This week
# 184            0.000000          1.0  This week
# 196         4682.000000          1.0  This week
# 201            0.000000          1.0  This week
# 203         2395.000000          1.0  This week
# 235            0.000000          1.0  This week
# 238            0.000000          1.0  This week

# %% [markdown]
# ## Cleaning Locations

# %%
sorted_list = sorted(jobs['Location'].unique())
print(sorted_list)
# Out:
# ['Alkmaar', 'Almere', 'Amersfoort', 'Amstelveen', 'Amsterdam', 'Amsterdam Centrum', 'Amsterdam Nieuw-West', 'Amsterdam West', 'Amsterdam Zuid', 'Amsterdam-Zuidoost', 'Apeldoorn', 'Arnhem', 'Baarn', 'Born', 'Breda', 'Breukelen', 'Bronkhorst', 'Capelle aan den IJssel', 'Culemborg', 'Delft', 'Den Bosch', 'Den Haag', 'Den Haag Centrum', 'Deventer', 'Diemen', 'Doesburg', 'Dordrecht', 'Driebergen', 'Driebergen-Rijsenburg', 'Eindhoven', 'Enschede', 'Fijnaart', 'Gemeente Hardinxveld-Giessendam', 'Gooi', 'Groningen', 'Harderwijk', 'Heerlen', 'Hengelo OV', 'Hilversum', 'Hoofddorp', 'Houten', 'Huizen', 'IJsselstein', 'Kampen', 'Laren', 'Leeuwarden', 'Leiden', 'Leusden', 'Maastricht', 'Made', 'Middelburg', 'Naarden', 'Nederland', 'Nieuw-Vennep', 'Nijmegen', 'Oirschot', 'Oss', 'Raalte', 'Randstad', 'Renswoude', 'Rijssen', 'Rijswijk', 'Rotterdam', 'Rotterdam Centrum', 'Rotterdam Feijenoord', 'Rotterdam Maasvlakte', 'Rotterdam Overschie', 'Schiedam', 'Schiphol', 'Slochteren', 'Tiel', 'Tilburg', 'Twente', 'Utrecht', 'Utrecht Binnenstad', 'Utrecht Leidsche Rijn', 'Utrecht Oost', 'Utrecht Zuidwest', 'Veenendaal', 'Veldhoven', 'Waalwijk', 'Waddinxveen', 'Wageningen', 'Werk van thuis', 'Willemstad Curaçao', 'Woerden', 'Zaandam', 'Zeist', 'Zoetermeer', 'Zutphen', 'Zwolle']

# %%
jobs['Location'].value_counts().sum()
# Out:
# 413

# %%
big_cities = ['amsterdam', 'utrecht', 'den haag', 'rotterdam']

# %%
def city_clean(x):
    x = x.replace('-', ' ')
    for city in big_cities:
        if re.search(city, x.lower()):
            x = x.split(' ')[0]
            if x == 'Den':
                x = 'Den Haag'
    return x

jobs['Location Grouped'] = jobs['Location'].apply(lambda x: city_clean(x))

# %%
jobs.Location.value_counts()
# Out:
# Amsterdam                87
# Den Bosch                28
# Utrecht                  25
# Rotterdam                20
# Den Haag                 20
#                          ..
# Driebergen-Rijsenburg     1
# Werk van thuis            1
# IJsselstein               1
# Waalwijk                  1
# Naarden                   1
# Name: Location, Length: 91, dtype: int64

# %% [markdown]
# Final check of the data

# %%
jobs.head()
# Out:
#                                                 Title  Location  \
# 0                                      Data Scientist  Den Haag
# 10            Director Business Analysis and Planning  Schiphol
# 14                      Chapter Lead Data Engineering    Diemen
# 15                                 Database Marketeer  Schiedam
# 17  Business Analyst with an Asset Management spec...   Utrecht
#
#                         Company                     Salary              Since  \
# 0                          HAYS                        NaN      Net geplaatst
# 10               Liberty Global                        NaN  Vandaag geplaatst
# 14                   Tempo-Team  €4.000 - €5.400 per maand  Vandaag geplaatst
# 15  Lefit Recruitment & Interim                        NaN  Vandaag geplaatst
# 17            De Staffing Groep                        NaN  Vandaag geplaatst
#
#     Description             Company Url                      Industry  \
# 0           NaN               /cmp/Hays  Human resources en personeel
# 10          NaN     /cmp/Liberty-Global                           NaN
# 14          NaN        /cmp/Tempo--team  Human resources en personeel
# 15          NaN                     NaN                           NaN
# 17          NaN  /cmp/De-Staffing-Groep                           NaN
#
#         Company size     Title Grouped  Min Salary  Max Salary    Salary Type  \
# 0   5.001 tot 10.000    Data Scientist         NaN         NaN  Not Specified
# 10   Meer dan 10.000  Business Analyst         NaN         NaN  Not Specified
# 14   1.001 tot 5.000     Data Engineer      4000.0      5400.0        Monthly
# 15               NaN             Other         NaN         NaN  Not Specified
# 17               NaN  Business Analyst         NaN         NaN  Not Specified
#
#     Normalized Sal Min  Normalized Sal Max  Normalized Sal Avg  Posted_days  \
# 0                  0.0                 0.0                 0.0          0.0
# 10                 0.0                 0.0                 0.0          0.0
# 14              4000.0              5400.0              4700.0          0.0
# 15                 0.0                 0.0                 0.0          0.0
# 17                 0.0                 0.0                 0.0          0.0
#
#        Posted Location Grouped
# 0   This week         Den Haag
# 10  This week         Schiphol
# 14  This week           Diemen
# 15  This week         Schiedam
# 17  This week          Utrecht

# %%
jobs.drop(columns={'Description', 'Company Url'}, inplace=True)

# %% [markdown]
# #### Cleaning Industries

# %%
jobs[jobs['Industry'].isnull()].groupby('Company').count().sort_values(by='Title', ascending=False)
# Out:
#                                Title  Location  Salary  Since  Industry  \
# Company
# CareerValue                       38        38      14     38         0
# MagnaVersum                        9         9       0      9         0
# Darwin Recruitment                 8         8       6      8         0
# Yacht                              6         6       0      6         0
# My Jewellery                       6         6       0      6         0
# ...                              ...       ...     ...    ...       ...
# KPI Solutions B.V.                 1         1       0      1         0
# Ipreo                              1         1       0      1         0
# International Travel Group         1         1       0      1         0
# Impact Information Management      1         1       0      1         0
# mySendle                           1         1       0      1         0
#
#                                Company size  Title Grouped  Min Salary  \
# Company
# CareerValue                               0             38          14
# MagnaVersum                               0              9           0
# Darwin Recruitment                        8              8           6
# Yacht                                     0              6           0
# My Jewellery                              0              6           0
# ...                                     ...            ...         ...
# KPI Solutions B.V.                        0              1           0
# Ipreo                                     0              1           0
# International Travel Group                0              1           0
# Impact Information Management             0              1           0
# mySendle                                  0              1           0
#
#                                Max Salary  Salary Type  Normalized Sal Min  \
# Company
# CareerValue                            14           38                  38
# MagnaVersum                             0            9                   9
# Darwin Recruitment                      6            8                   8
# Yacht                                   0            6                   6
# My Jewellery                            0            6                   6
# ...                                   ...          ...                 ...
# KPI Solutions B.V.                      0            1                   1
# Ipreo                                   0            1                   1
# International Travel Group              0            1                   1
# Impact Information Management           0            1                   1
# mySendle                                0            1                   1
#
#                                Normalized Sal Max  Normalized Sal Avg  \
# Company
# CareerValue                                    38                  38
# MagnaVersum                                     9                   9
# Darwin Recruitment                              8                   8
# Yacht                                           6                   6
# My Jewellery                                    6                   6
# ...                                           ...                 ...
# KPI Solutions B.V.                              1                   1
# Ipreo                                           1                   1
# International Travel Group                      1                   1
# Impact Information Management                   1                   1
# mySendle                                        1                   1
#
#                                Posted_days  Posted  Location Grouped
# Company
# CareerValue                             38      38                38
# MagnaVersum                              9       9                 9
# Darwin Recruitment                       8       8                 8
# Yacht                                    6       6                 6
# My Jewellery                             6       6                 6
# ...                                    ...     ...               ...
# KPI Solutions B.V.                       1       1                 1
# Ipreo                                    1       1                 1
# International Travel Group               1       1                 1
# Impact Information Management            1       1                 1
# mySendle                                 1       1                 1
#
# [160 rows x 16 columns]

# %%
jobs.to_csv('jobs_cleaned_final.csv', index=False)

# %%
# import required libraries to connet to MySQL Database
import pymysql 
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:xxxxx@localhost:3306/data_jobs_nl')

# %%
jobs.to_sql('jobs_last_30', engine, if_exists='replace', index=False)
