# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
result = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=1&per_page=100') 
result2 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=2&per_page=100')

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here 
forks = result.json()  + result2.json() 

languages = []

for f in forks:
    f = f['language']
    languages.append(f)
    
print(languages) 

print(len(forks))
# Out:
# ['Jupyter Notebook', None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, None, 'Jupyter Notebook', 'Jupyter Notebook', None, None, None, None, None, None, None, 'Jupyter Notebook', None, None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, None, None, None, None, None, 'Jupyter Notebook', None, None, 'Jupyter Notebook', None, None, None, 'Jupyter Notebook', 'Jupyter Notebook', None, None, 'Jupyter Notebook', None, 'Jupyter Notebook', None, None, None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, 'AGS Script', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Ju
# ...

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

result = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=1&per_page=100&since=2019-10-01T00:00:00Z&until=2019-10-31T23:59:59Z')
result2 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=2&per_page=100&since=2019-10-01T00:00:00Z&until=2019-10-31T23:59:59Z')
# #YYYY-MM-DDTHH:MM:SS

# result = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?since=2019-10-01T00:00:00Z&until=2019-10-30T00:00:00Z')
# result2 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=2&per_page=100since=2019-10-01T00:00:00Z&until=2019-10-30T00:00:00Z')

commits =result.json() + result2.json()
commits
# Out:
# [{'sha': '37e0b0681ff829d1c9f4a542631229efe7d577ff',
#   'node_id': 'MDY6Q29tbWl0MjEzNjQxMTcwOjM3ZTBiMDY4MWZmODI5ZDFjOWY0YTU0MjYzMTIyOWVmZTdkNTc3ZmY=',
#   'commit': {'author': {'name': 'kelsey-ironhack',
#     'email': '52278191+kelsey-ironhack@users.noreply.github.com',
#     'date': '2019-10-22T14:49:41Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-10-22T14:49:41Z'},
#    'message': 'add',
#    'tree': {'sha': '4ae3efe8bcf67821547d79c22513ac8cccefa863',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/dataV2-labs/git/trees/4ae3efe8bcf67821547d79c22513ac8cccefa863'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/dataV2-labs/git/commits/37e0b0681ff829d1c9f4a542631229efe7d577ff',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here 
count_commits = sum(1 for line in commits) 
print(f"There are {count_commits} commit objects")
# Out:
# There are 142 commit objects

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here 

results = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger?filename:scavengerhunt')

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here 
scavenger = results.json()
scavenger
# Out:
# {'id': 162375181,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#  'name': 'scavenger',
#  'full_name': 'ironhack-datalabs/scavenger',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
