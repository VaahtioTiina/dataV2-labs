# %% [markdown]
# #### Correlations Lab

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read data 

cdd = pd.read_csv('CDD.csv', sep='\t')

# %%
cdd.head()
# Out:
#   EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0       Disaster     Natural  Meteorological - Hydrological
# 1       Disaster     Natural  Meteorological - Hydrological
# 2       Disaster     Natural  Meteorological - Hydrological
# 3       Disaster     Natural                     Biological
# 4       Incident  Technology            Hazardous Chemicals
#
#                     EVENT TYPE                                 PLACE  \
# 0  Storm - Unspecified / Other                   Christmas Island NS
# 1                 Winter Storm  Nova Scotia and Prince Edward Island
# 2                        Flood             Red Earth First Nation SK
# 3                     Epidemic              Alberta and Saskatchewan
# 4         Leak / Spill Release                   Seaforth Channel BC
#
#          EVENT START DATE                                           COMMENTS  \
# 0  25/12/2016 12:00:00 AM  Christmas Island NS, December 25, 2016. Reside...
# ...

# %%
cdd.describe()
# Out:
#          FATALITIES  INJURED / INFECTED      EVACUATED  ESTIMATED TOTAL COST  \
# count   1000.000000        9.740000e+02    1019.000000          5.580000e+02
# mean      63.527000        2.088787e+03    1150.980373          4.839952e+07
# std     1583.137131        6.408480e+04    9261.735376          3.045786e+08
# min        0.000000        0.000000e+00       0.000000          0.000000e+00
# 25%        0.000000        0.000000e+00       0.000000          0.000000e+00
# 50%        0.000000        0.000000e+00       0.000000          4.621430e+05
# 75%        2.000000        0.000000e+00     200.000000          9.526868e+06
# max    50000.000000        2.000000e+06  225000.000000          4.635720e+09
#
#        NORMALIZED TOTAL COST  FEDERAL DFAA PAYMENTS  PROVINCIAL DFAA PAYMENTS  \
# count           5.580000e+02           4.850000e+02              4.110000e+02
# mean            2.870350e+06           1.194386e+07              1.521750e+06
# ...

# %%
cdd.shape
# Out:
# (1089, 22)

# %%
cdd.isnull().sum()
# Out:
# EVENT CATEGORY                       0
# EVENT GROUP                          0
# EVENT SUBGROUP                       0
# EVENT TYPE                           0
# PLACE                                0
# EVENT START DATE                     0
# COMMENTS                             0
# FATALITIES                          89
# INJURED / INFECTED                 115
# EVACUATED                           70
# ESTIMATED TOTAL COST               531
# NORMALIZED TOTAL COST              531
# EVENT END DATE                       0
# FEDERAL DFAA PAYMENTS              604
# PROVINCIAL DFAA PAYMENTS           678
# PROVINCIAL DEPARTMENT PAYMENTS     997
# MUNICIPAL COSTS                   1060
# OGD COSTS                         1075
# INSURANCE PAYMENTS                1017
# NGO PAYMENTS                      1081
# UTILITY - PEOPLE AFFECTED           83
# MAGNITUDE                          114
# dtype: int64

# %%
cdd.dtypes
# Out:
# EVENT CATEGORY                     object
# EVENT GROUP                        object
# EVENT SUBGROUP                     object
# EVENT TYPE                         object
# PLACE                              object
# EVENT START DATE                   object
# COMMENTS                           object
# FATALITIES                        float64
# INJURED / INFECTED                float64
# EVACUATED                         float64
# ESTIMATED TOTAL COST              float64
# NORMALIZED TOTAL COST             float64
# EVENT END DATE                     object
# FEDERAL DFAA PAYMENTS             float64
# PROVINCIAL DFAA PAYMENTS          float64
# PROVINCIAL DEPARTMENT PAYMENTS    float64
# MUNICIPAL COSTS                   float64
# OGD COSTS                         float64
# INSURANCE PAYMENTS                float64
# NGO PAYMENTS                      float64
# UTILITY - PEOPLE AFFECTED         float64
# MAGNITUDE                         float64
# dtype: object

# %% [markdown]
# #### Correlation Matrix

# %%
cdd.corr().min()
# Out:
# FATALITIES                       -0.023630
# INJURED / INFECTED               -0.036915
# EVACUATED                        -0.005672
# ESTIMATED TOTAL COST              0.027839
# NORMALIZED TOTAL COST             0.031352
# FEDERAL DFAA PAYMENTS            -0.021965
# PROVINCIAL DFAA PAYMENTS         -0.020317
# PROVINCIAL DEPARTMENT PAYMENTS   -0.026786
# MUNICIPAL COSTS                   0.078196
# OGD COSTS                        -0.092983
# INSURANCE PAYMENTS                0.241347
# NGO PAYMENTS                      0.838898
# UTILITY - PEOPLE AFFECTED        -0.092983
# MAGNITUDE                        -0.005672
# dtype: float64

# %%
# Drop na 
fig, ax = plt.subplots(figsize=(15,10)) 
ax = sns.heatmap(cdd.corr(), annot=True, linewidths=0.5, ax=ax)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (14.5, -0.5)

# %% [markdown]
# Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero and one pair that is negatively correlated. In each case write down an explanation why we see this correlation

# %%
# First pair - High correlation 
# Injured/Infected and municipal cost - corr 0.97  
print("The correlation between municipal cost and injured/infected is high, as it is natural that the more injuries there are \n the higher the cost for the municipality is.")
# Out:
# The correlation between municipal cost and injured/infected is high, as it is natural that the more injuries there are
#  the higher the cost for the municipality is.

# %%
# Second pair - Almost zero correlation
# Fatalities and Evacuated correlation -0.0035 
print("There is almost no correlation between fatalities and evacuated. This is interesting as we would maybe expect the fatalities to decrease when evacuation goes up.")
# Out:
# There is almost no correlation between fatalities and evacuated. This is interesting as we would maybe expect the fatalities to decrease when evacuation goes up.

# %%
# Third paid - Negative correlation 
# There is not really a highyl negatively correlated values. The most negatively correlated is ODG Costs - Utility-People Affected which is -.093
# This means almost no correlation 

print("There are no strongly negatively correlated attributes in this dataset. This makes sense as the type of data we are looking at \nis costs and number of people affected, hence naturally the negative correlations are very slight and not significant.")
# Out:
# There are no strongly negatively correlated attributes in this dataset. This makes sense as the type of data we are looking at
# is costs and number of people affected, hence naturally the negative correlations are very slight and not significant.

# %% [markdown]
# Plotting the pairs

# %%
# First Pair 
sns.pairplot(cdd, vars=["INJURED / INFECTED", "MUNICIPAL COSTS"], kind='reg')

# %% [markdown]
# The regression line helps us identify that there is a trend and positive correlation. However, we should check the data points more carefully the look for outliers and null values to draw better conclusions.

# %%
sns.pairplot(cdd, vars=["FATALITIES", "EVACUATED"], kind='reg')

# %% [markdown]
# As our regression trend line shows here it's almost straight without a slope which mean that the data is spread out accross the plot and does not form a correlation

# %%
sns.pairplot(cdd, vars=["OGD COSTS", "UTILITY - PEOPLE AFFECTED"], kind='reg')

# %% [markdown]
# Here we see a light negative slope, but as mentioned before the slope is so small that it basically means no correlation.

# %%
# As an extra correlation with more data points
sns.pairplot(cdd, vars=["ESTIMATED TOTAL COST", "EVACUATED"], kind='reg')
