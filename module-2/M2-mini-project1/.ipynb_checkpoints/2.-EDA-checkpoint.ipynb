# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879     61.749336     57.457029   3932.136079      5.732007
# std        0.473986      1.432514      2.234064   3988.734835      1.119670
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity_scale   color_scale
# count  53932.000000  53932.000000   53932.000000  53932.000000
# mean       5.734142      3.539734       3.051101      3.405789
# std        1.113272      0.692050       1.647109      1.701165
# min        3.680000      1.070000       0.000000      0.000000
# 25%        4.720000      2.910000       2.000000      2.000000
# 50%        5.710000      3.530000       3.000000      3.000000
# 75%        6.540000      4.040000       4.000000      5.000000
# max       19.270000      8.060000       7.000000      6.000000

# %%
#your comments here
"""
For price the range is from 326 - 18823. The maximum values are way higher than upper quartile , 
however, this is natural as we have a few premium diamonds with a large size.
"""
# Out:
# '\nFor price the range is from 326 - 18823. The maximum values are way higher than upper quartile , \nhowever, this is natural as we have a few premium diamonds with a large size.\n'

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here 

"""
Most likely the carat (the weight of the diamond), clarity (quality), and color (the least color, the more rare and more expensive). 
"""
# Out:
# '\nMost likely the carat (the weight of the diamond), clarity (quality), and color (the least color, the more rare and more expensive). \n'

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here 
d_col = diamonds.groupby(['color', 'color_scale']).mean()
d_col.head(10)
# Out:
#                       carat      depth      table        price         x  \
# color color_scale
# D     6            0.657715  61.698066  57.404355  3168.106436  5.417851
# E     5            0.657867  61.662090  57.491201  3076.752475  5.411580
# F     4            0.736509  61.694087  57.433148  3725.091938  5.616727
# G     3            0.771088  61.757449  57.288060  3998.145173  5.678549
# H     2            0.911627  61.836557  57.518176  4484.958805  5.984776
# I     1            1.026927  61.846385  57.577278  5091.874954  6.222826
# J     0            1.162137  61.887215  57.812393  5323.818020  6.519338
#
#                           y         z  clarity_scale
# color color_scale
# D     6            5.421928  3.343320       2.691025
# E     5            5.416948  3.337767       2.969889
# F     4            5.620529  3.465937       3.134605
# G     3            5.681198  3.507965       3.463419
# H     2            5.981483  3.699145       2.933871
# I     1            6.222726  3.846368       2.964035
# J     0            6.518127  4.033251       2.776353

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here 
"""
As expected the average price follows the color scale, so that color scale 0 has the highest mean. As anticipated in the hypothesis

Moreover, looks like color scale 0 has the highest carats and the lowest color scale the one fo the smallest. 
"""
# Out:
# '\nAs expected the average price follows the color scale, so that color scale 0 has the highest mean. As anticipated in the hypothesis\n\nMoreover, looks like color scale 0 has the highest carats and the lowest color scale the one fo the smallest. \n'

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here 
color_freq = sns.distplot(diamonds['color_scale'], bins=6, kde=False)
color_freq

# %%
#your comments here 
"""
Seems like there is the most diamonds at the worst end of the color scale(6). This is natural as the color 0 and 1 are rare finds.
"""
# Out:
# '\nSeems like there is the most diamonds at the worst end of the color scale(6). This is natural as the color 0 and 1 are rare finds.\n'

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds_c = diamonds.groupby('carat').mean() 
diamonds_c.shape
# Out:
# (273, 8)

# %%
# Too many individual values lets bin them
diamonds_c = diamonds.groupby([pd.qcut(diamonds.carat,q=10)]).mean()
diamonds_c.head(10)
# Out:
#                   carat      depth      table         price         x  \
# carat
# (0.199, 0.31]  0.292461  61.767297  57.018273    655.294017  4.263985
# (0.31, 0.35]   0.330877  61.641316  56.707534    750.733174  4.452505
# (0.35, 0.42]   0.395547  61.681166  57.008781    922.498432  4.716373
# (0.42, 0.53]   0.497004  61.748081  57.172464   1486.054642  5.085405
# (0.53, 0.7]    0.621343  61.611601  57.363762   2090.247266  5.474628
# (0.7, 0.9]     0.785144  61.854846  57.609366   3096.292948  5.901931
# (0.9, 1.01]    0.986128  61.995391  58.327201   5039.189482  6.354834
# (1.01, 1.13]   1.062542  61.626815  57.530249   5825.203193  6.555521
# (1.13, 1.51]   1.311906  61.786364  57.811504   7943.242479  7.007425
# (1.51, 5.01]   1.859866  61.734967  58.063156  12935.207425  7.862450
#
#                       y         z  clarity_scale  color_scale
# carat
# (0.199, 0.31]  4.276215  2.637094       4.144606     3.740856
# (0.31, 0.35]   4.458908  2.746001       3.820669     3.641554
# (0.35, 0.42]   4.725905  2.911710       3.617229     3.803726
# (0.42, 0.53]   5.092536  3.141939       3.277517     3.933999
# (0.53, 0.7]    5.481971  3.374431       3.121750     3.730859
# (0.7, 0.9]     5.908872  3.652258       2.654706     3.467537
# (0.9, 1.01]    6.349360  3.937030       2.371873     3.568840
# (1.01, 1.13]   6.552625  4.037964       2.506343     3.227690
# (1.13, 1.51]   6.997185  4.325476       2.642479     2.636529
# (1.51, 5.01]   7.848629  4.848640       2.132528     2.181524

# %%
#your comments 
"""
Yes it seems the higher the weight of diamonds, the higher the price. 
"""
# Out:
# '\nYes it seems the higher the weight of diamonds, the higher the price. \n'

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
carat_freq = sns.distplot(diamonds['carat'], bins=15)
carat_freq

# %%
"""
There are much more less weighting diamonds than big ones. 
"""
# Out:
# '\nThere are much more less weighting diamonds than big ones. \n'

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds_t = diamonds.groupby('table').mean() 
diamonds_t.shape
# Out:
# (127, 8)

# %%
# As in the previous I prefer grouping the data a bit more to bins
diamonds_t = diamonds.groupby([pd.qcut(diamonds.table,q=7)]).mean()
diamonds_t.head(10)
# Out:
#                    carat      depth      table        price         x  \
# table
# (42.999, 55.0]  0.664116  62.175795  54.564953  3064.697998  5.391862
# (55.0, 56.0]    0.712435  61.971675  55.991557  3385.789725  5.530330
# (56.0, 57.0]    0.785997  61.920238  56.993274  3885.601341  5.706766
# (57.0, 58.0]    0.864846  61.830876  57.995065  4407.015503  5.887021
# (58.0, 59.0]    0.894103  61.578577  58.995876  4602.993352  5.958296
# (59.0, 60.0]    0.925942  61.233450  59.994522  4870.556410  6.038166
# (60.0, 95.0]    0.909201  60.622869  62.024004  4345.560991  6.041684
#
#                        y         z  clarity_scale  color_scale
# table
# (42.999, 55.0]  5.404035  3.356696       3.415811     3.435931
# (55.0, 56.0]    5.537755  3.430251       3.296894     3.532656
# (56.0, 57.0]    5.712136  3.535513       3.106980     3.428731
# (57.0, 58.0]    5.886431  3.640516       2.886627     3.337870
# (58.0, 59.0]    5.953918  3.667855       2.823387     3.303369
# (59.0, 60.0]    6.030793  3.695928       2.695804     3.363170
# (60.0, 95.0]    6.027955  3.657948       2.599794     3.331063

# %%
#your comments here
"""
It also seems that that higher the table value the pricier the diamond gets.  
"""
# Out:
# '\nIt also seems that that higher the table value the pricier the diamond gets.  \n'

# %%
table_freq = sns.distplot(diamonds['table'], bins=20, kde=False)
table_freq

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds_cla = diamonds.groupby('clarity_scale').mean()
diamonds_cla.head(7)
# Out:
#                   carat      depth      table        price         x  \
# clarity_scale
# 0              1.283846  62.734278  58.303779  3924.168691  6.761093
# 1              1.077602  61.771567  57.926823  5062.267356  6.404157
# 2              0.850482  61.853042  57.662541  3996.001148  5.888383
# 3              0.763850  61.724249  57.418040  3924.166204  5.658633
# 4              0.727108  61.667968  57.313966  3839.144308  5.572860
# 5              0.596202  61.663778  57.024990  3283.737071  5.218454
# 6              0.503131  61.624521  56.883881  2519.512315  4.961721
#
#                       y         z  color_scale
# clarity_scale
# 0              6.709433  4.224683     2.968961
# 1              6.395578  3.952640     3.469967
# 2              5.888256  3.640635     3.448450
# 3              5.659782  3.492786     3.494370
# 4              5.580016  3.437924     3.161812
# 5              5.232118  3.221465     3.569483
# 6              4.976437  3.062132     3.350848

# %%
#your comments here 
"""
Clarity does not seem to have as clear effect on price as the other variables examined. However seems that it still is somewhat correlated.
We should examine this a little bit in more detail with correlations
"""
# Out:
# '\nClarity does not seem to have as clear effect on price as the other variables examined. However seems that it still is somewhat correlated.\nWe should examine this a little bit in more detail with correlations\n'

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here 
"""
The same as previously, however, I would add table to factors and point out that clarity has at least less affect than expected in the hypothesis
"""
# Out:
# '\nThe same as previously, however, I would add table to factors and point out that clarity has at least less affect than expected in the hypothesis\n'

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

"""
In these graphs it seems that actually the correlation of the depth, table is unclearar than expected.
Moreover we would need to seperate the clarity and color scales to bigger image to make sense of them
"""
# Out:
# '\nIn these graphs it seems that actually the correlation of the depth, table is unclearar than expected.\nMoreover we would need to seperate the clarity and color scales to bigger image to make sense of them\n'

# %%
g = sns.pairplot(diamonds, vars=['color_scale','clarity_scale', 'price'], diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 60, 'edgecolor': 'k'})
g.fig.set_size_inches(10,10)

# %%
"""
And seems like there is not so much correlation between the prices and the color scale and clarity.
"""
# Out:
# '\nAnd seems like there is not so much correlation between the prices and the color scale and clarity.\n'

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
"""
Yes it fits. The correlation additonally confirmed that the correlation between clarity and color is not that strong. 
"""
# Out:
# '\nYes it fits. The correlation additonally confirmed that the correlation between clarity and color is not that strong. \n'

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
print(f'r2 : {r2}, p-value: {p_value}, std_err: {std_err}')
# Out:
# r2 : 0.8493658995804609, p-value: 0.0, std_err: 14.06424017321538

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here 
"""
The model represents the data well.
"""
# Out:
# '\nThe model represents the data well.\n'

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
